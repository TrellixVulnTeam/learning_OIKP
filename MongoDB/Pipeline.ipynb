# %%
import pymongo
from pprint import pprint
import pandas as pd
import numpy as np
from IPython.display import Image

connection =pymongo.MongoClient("localhost",27017)
db = connection.python

for i in db.list_collection_names():
    print(i)
# Out:
# posts
# sudo
# fs.files
# chat
# sales
# login
# funds
# users
# limited
# fs.chunks
# nei
# airbnb
# res

# %%
#reference 
for i in db.airbnb.find().limit(1):
    pprint(i)
# Out:
# {'_id': '10021707',
#  'access': '',
#  'accommodates': 1,
#  'address': {'country': 'United States',
#              'country_code': 'US',
#              'government_area': 'Bushwick',
#              'location': {'coordinates': [-73.93615, 40.69791],
#                           'is_location_exact': True,
#                           'type': 'Point'},
#              'market': 'New York',
#              'street': 'Brooklyn, NY, United States',
#              'suburb': 'Brooklyn'},
#  'amenities': ['Internet',
#                'Wifi',
#                'Air conditioning',
#                'Kitchen',
#                'Buzzer/wireless intercom',
#                'Heating',
#                'Smoke detector',
#                'Carbon monoxide detector',
#                'Essentials',
#                'Lock on bedroom door'],
#  'availability': {'availability_30': 0,
#                   'availability_365': 0,
#                   'availability_60': 0,
#                   'availability_90': 0},
#  'bathrooms': Decimal128('1.5'),
#  'bed_type': 'Real Bed',
#  'bedrooms': 1,
#  'beds': 1,
#  'calendar_last_scraped': datetime.datetime(2019, 3, 6, 5, 0),
#  'cancellation_policy': 'flexible',
#  'description': 'Here exists a very cozy room for rent in a shared 4-bedroom '
#                 'apartment. It is located one block off of the JMZ at Myrtle '
#                 'Broadway.  The neighborhood is diverse and appeals to a '
#                 'variety of people.',
#  'extra_people': Decimal128('0.00'),
#  'first_review': datetime.datetime(2016, 1, 31, 5, 0),
#  'guests_included': Decimal128('1'),
#  'host': {'host_about': '',
#           'host_has_profile_pic': True,
#           'host_id': '11275734',
#           'host_identity_verified': True,
#           'host_is_superhost': False,
#           'host_listings_count': 1,
#           'host_location': 'New York, New York, United States',
#           'host_name': 'Josh',
#           'host_neighbourhood': 'Bushwick',
#           'host_picture_url': 'https://a0.muscache.com/im/users/11275734/profile_pic/1405792127/original.jpg?aki_policy=profile_x_medium',
#           'host_thumbnail_url': 'https://a0.muscache.com/im/users/11275734/profile_pic/1405792127/original.jpg?aki_policy=profile_small',
#           'host_total_listings_count': 1,
#           'host_url': 'https://www.airbnb.com/users/show/11275734',
#           'host_verifications': ['email', 'phone', 'reviews', 'kba']},
#  'house_rules': '',
#  'images': {'medium_url': '',
#             'picture_url': 'https://a0.muscache.com/im/pictures/72844c8c-fec2-440e-a752-bba9b268c361.jpg?aki_policy=large',
#             'thumbnail_url': '',
#             'xl_picture_url': ''},
#  'interaction': '',
#  'last_review': datetime.datetime(2016, 1, 31, 5, 0),
#  'last_scraped': datetime.datetime(2019, 3, 6, 5, 0),
#  'listing_url': 'https://www.airbnb.com/rooms/10021707',
#  'maximum_nights': '1125',
#  'minimum_nights': '14',
#  'name': 'Private Room in Bushwick',
#  'neighborhood_overview': '',
#  'notes': '',
#  'number_of_reviews': 1,
#  'price': Decimal128('40.00'),
#  'property_type': 'Apartment',
#  'review_scores': {'review_scores_accuracy': 10,
#                    'review_scores_checkin': 10,
#                    'review_scores_cleanliness': 10,
#                    'review_scores_communication': 10,
#                    'review_scores_location': 8,
#                    'review_scores_rating': 100,
#                    'review_scores_value': 8},
#  'reviews': [{'_id': '61050713',
#               'comments': 'Josh was out of town during my 1 month stay. His '
#                           'roommates greeted and helped get me settled. They '
#                           "were great hosts and all around cool people. I'm a "
#                           'Brooklynite, but have never lived in Bushwick.\r\n'
#                           "If you're looking for an hip, authentic, and "
#                           'convenient Brooklyn experience, this spot is for '
#                           'you.  You can literally see the Subway platform '
#                           "from Josh's window. Also a couple steps away from "
#                           'anything you could possibly need... restaurants, '
#                           'juice bar, organic grocery, etc. ',
#               'date': datetime.datetime(2016, 1, 31, 5, 0),
#               'listing_id': '10021707',
#               'reviewer_id': '52006105',
#               'reviewer_name': 'Antoine'}],
#  'room_type': 'Private room',
#  'space': '',
#  'summary': 'Here exists a very cozy room for rent in a shared 4-bedroom '
#             'apartment. It is located one block off of the JMZ at Myrtle '
#             'Broadway.  The neighborhood is diverse and appeals to a variety '
#             'of people.',
#  'transit': ''}

# %% [markdown]
# #### \$group

# %%
#country코드가 얼마나 유니크한가 알아보자? -> group

for i in db.airbnb.aggregate([{"$match" :{"address.country_code":{"$ne":"US"}}},
                             {"$group":{"_id":{"CountryName":"$address.country"}}}]):
    pprint(i)
# Out:
# {'_id': {'CountryName': 'Hong Kong'}}
# {'_id': {'CountryName': 'Turkey'}}
# {'_id': {'CountryName': 'Spain'}}
# {'_id': {'CountryName': 'Portugal'}}
# {'_id': {'CountryName': 'Brazil'}}
# {'_id': {'CountryName': 'Canada'}}
# {'_id': {'CountryName': 'China'}}
# {'_id': {'CountryName': 'Australia'}}

# %% [markdown]
# #### \$filter

# %%
#리뷰숫자가 5개이상 되는걸 뽑아보자. 
#method1 
for i in db.airbnb.aggregate([{"$match":{"reviews":{"$exists":True}}},
                              {"$match":{"$expr":{"$gt": [{"$size":"$reviews"},5]}}},
                              {"$limit":1}]):
    pprint(i)
# Out:
# {'_id': '10038496',
#  'access': 'todo o espaço.',
#  'accommodates': 4,
#  'address': {'country': 'Brazil',
#              'country_code': 'BR',
#              'government_area': 'Copacabana',
#              'location': {'coordinates': [-43.190849194463404,
#                                           -22.984339360067814],
#                           'is_location_exact': False,
#                           'type': 'Point'},
#              'market': 'Rio De Janeiro',
#              'street': 'Rio de Janeiro, Rio de Janeiro, Brazil',
#              'suburb': 'Copacabana'},
#  'amenities': ['TV',
#                'Cable TV',
#                'Internet',
#                'Wifi',
#                'Air conditioning',
#                'Kitchen',
#                'Paid parking off premises',
#                'Smoking allowed',
#                'Doorman',
#                'Elevator',
#                'Buzzer/wireless intercom',
#                'Family/kid friendly',
#                'Washer',
#                'Fire extinguisher',
#                'Essentials',
#                'Hangers',
#                'Hair dryer',
#                'Iron',
#                'Laptop friendly workspace',
#                'Hot water',
#                'Bed linens',
#                'Extra pillows and blankets',
#                'Microwave',
#                'Coffee maker',
#                'Refrigerator',
#                'Dishes and silverware',
#                'Oven',
#                'Stove',
#                'Long term stays allowed',
#                'Wide hallway clearance',
#                'Host greets you'],
#  'availability': {'availability_30': 7,
#                   'availability_365': 118,
#                   'availability_60': 19,
#                   'availability_90': 33},
#  'bathrooms': Decimal128('2.0'),
#  'bed_type': 'Real Bed',
#  'bedrooms': 1,
#  'beds': 3,
#  'calendar_last_scraped': datetime.datetime(2019, 2, 11, 5, 0),
#  'cancellation_policy': 'strict_14_with_grace_period',
#  'cleaning_fee': Decimal128('150.00'),
#  'description': 'The Apartment has a living room, toilet, bedroom (suite) and '
#                 'American kitchen. Well located, on the Copacabana beach block '
#                 'a 05 Min. walk from Ipanema beach (Arpoador). Internet wifi, '
#                 'cable tv, air conditioning in the bedroom, ceiling fans in '
#                 'the bedroom and living room, kitchen with microwave, cooker, '
#                 'Blender, dishes, cutlery and service area with fridge, '
#                 'washing machine, clothesline for drying clothes and closet '
#                 'with several utensils for use.  The property boasts 45 m2. '
#                 'The apartment has a living room, wash room, suite and an '
#                 "American kitchen. The bedroom has a double bed and there's a "
#                 'bunk bed in the living room. It is very well located, in the '
#                 'Copacabana beach block and just a few blocks from Arpoador '
#                 'and Ipanema. You can walk to any of those beaches. It has '
#                 'internet wifi, tv, air conditioning in the bedroom, ceiling '
#                 'fans in the living room and the bedroom and an equipped '
#                 'kitchen with cooker, fridge, washing machine, microwave and '
#                 'utensils. Ease of public transportation, banks, mar',
#  'extra_people': Decimal128('40.00'),
#  'first_review': datetime.datetime(2016, 1, 18, 5, 0),
#  'guests_included': Decimal128('3'),
#  'host': {'host_about': 'Professora de Educação Física formada pela '
#                         'universidade Gama Filho.',
#           'host_has_profile_pic': True,
#           'host_id': '51530266',
#           'host_identity_verified': True,
#           'host_is_superhost': True,
#           'host_listings_count': 2,
#           'host_location': 'Rio de Janeiro, State of Rio de Janeiro, Brazil',
#           'host_name': 'Ana Valéria',
#           'host_neighbourhood': 'Copacabana',
#           'host_picture_url': 'https://a0.muscache.com/im/pictures/8c7bb5fe-7b6d-4d03-a465-aae8971a87a0.jpg?aki_policy=profile_x_medium',
#           'host_response_rate': 100,
#           'host_response_time': 'within an hour',
#           'host_thumbnail_url': 'https://a0.muscache.com/im/pictures/8c7bb5fe-7b6d-4d03-a465-aae8971a87a0.jpg?aki_policy=profile_small',
#           'host_total_listings_count': 2,
#           'host_url': 'https://www.airbnb.com/users/show/51530266',
#           'host_verifications': ['email',
#                                  'phone',
#                                  'reviews',
#                                  'jumio',
#                                  'government_id']},
#  'house_rules': 'Entreguem o imóvel conforme receberam e respeitem as regras '
#                 'do condomínio para não serem incomodados.  Não danificar os '
#                 'utensílios e tudo que se refere as boas condições referentes '
#                 'ao mesmo . Não fazer barulho após às 22:00  até às 8:00. Usar '
#                 'entrada de serviço se estiver molhado voltando da praia.',
#  'images': {'medium_url': '',
#             'picture_url': 'https://a0.muscache.com/im/pictures/159d489e-62ad-44c4-80a0-fab2a8f3b455.jpg?aki_policy=large',
#             'thumbnail_url': '',
#             'xl_picture_url': ''},
#  'interaction': 'Contact telephone numbers if needed: Valeria ((PHONE NUMBER '
#                 'HIDDEN) (URL HIDDEN) ((PHONE NUMBER HIDDEN) cell phone (URL '
#                 'HIDDEN) (021) mobile/(PHONE NUMBER HIDDEN) José (URL '
#                 'HIDDEN)Concierge support; Fernando (caretaker boss) business '
#                 'hours.',
#  'last_review': datetime.datetime(2019, 1, 28, 5, 0),
#  'last_scraped': datetime.datetime(2019, 2, 11, 5, 0),
#  'listing_url': 'https://www.airbnb.com/rooms/10038496',
#  'maximum_nights': '75',
#  'minimum_nights': '3',
#  'name': 'Copacabana Apartment Posto 6',
#  'neighborhood_overview': 'Copacabana in the South zone is the district that '
#                           'offers the greatest number of options for tourists, '
#                           'transport, restaurants, banks, pharmacies and '
#                           'commerce in general are in abundance in all the '
#                           'blocks of the neighborhood.',
#  'notes': '',
#  'number_of_reviews': 70,
#  'price': Decimal128('119.00'),
#  'property_type': 'Apartment',
#  'review_scores': {'review_scores_accuracy': 10,
#                    'review_scores_checkin': 10,
#                    'review_scores_cleanliness': 10,
#                    'review_scores_communication': 10,
#                    'review_scores_location': 10,
#                    'review_scores_rating': 98,
#                    'review_scores_value': 10},
#  'reviews': [{'_id': '60037020',
#               'comments': 'Bom, foi uma experiencia incrível com a Ana e seu '
#                           'apartamento. Primeiramente ressalto a grande '
#                           'hospitalidade e prestatividade da anfitriã, na '
#                           'residência não tinha ferro de passar roupa '
#                           'solicitei e a mesma imediatamente comprou, deixou '
#                           'uns brindes na geladeira como água e cerveja, '
#                           'excelente tratamento.\r\n'
#                           'Sobre o apartamento, muito bem localizado e bem '
#                           'arrumado, camas bem confortáveis e tudo funcionando '
#                           'corretamente.\r\n'
#                           'Obrigado Ana, espero poder me hospedar em breve no '
#                           'seu ap.\r\n'
#                           '\r\n'
#                           'abraços',
#               'date': datetime.datetime(2016, 1, 18, 5, 0),
#               'listing_id': '10038496',
#               'reviewer_id': '44949795',
#               'reviewer_name': 'Valim'},
#              {'_id': '62079672',
#               'comments': 'Perfect location for Rio,very secure & very close '
#                           'to Copacabana and Ipanema beaches, the apartment is '
#                           'clean and very comfortable, all the equipment are '
#                           'included.\r\n'
#                           'The host Ana its so nice, it was always available '
#                           'for us to help us for anything in the city, I would '
#                           'definitely recommend her place and i will stay '
#                           'there again if I have the chance !',
#               'date': datetime.datetime(2016, 2, 11, 5, 0),
#               'listing_id': '10038496',
#               'reviewer_id': '47057044',
#               'reviewer_name': 'Nabil'},
#              {'_id': '63557342',
#               'comments': "I had an amazing time at Valeria's flat. \n"
#                           'The flat is great!!! Very very clean.\n'
#                           'The location is perfect!\n'
#                           'And on top of everything Valeria and her husband '
#                           'are fantastic host.\n'
#                           'I highly recommend it.',
#               'date': datetime.datetime(2016, 2, 24, 5, 0),
#               'listing_id': '10038496',
#               'reviewer_id': '669357',
#               'reviewer_name': 'Davi'},
#              {'_id': '68976444',
#               'comments': 'Ana y José hicieron que nos sintiéramos en casa '
#                           'desde el primer momento (nos recibieron con '
#                           'cervecitas fresquitas), siempre pendientes de lo '
#                           'que podíamos necesitar y muy predispuestos para dar '
#                           'consejos y ayuda. Muy preocupados por que el '
#                           'apartamento estuviera en perfectas condiciones.\r\n'
#                           'El Departamento es excelente, muy bien ubicado, ya '
#                           'que abajo hay un supermercado y en frente un '
#                           'Bradesco. Además muy completo, No nos faltó '
#                           'nada.\r\n'
#                           'Si volvemos a Río seguro pararemos nuevamente con '
#                           'Ana y José.\r\n',
#               'date': datetime.datetime(2016, 4, 8, 4, 0),
#               'listing_id': '10038496',
#               'reviewer_id': '15238005',
#               'reviewer_name': 'Agustin'},
#              {'_id': '87261130',
#               'comments': 'Local muito agradavel proximo do Mercado Zona Sul - '
#                           'padaria e comercio. Localizado a 1 quadra da praia. '
#                           'Ambiente agradavel host bem prestativa e muito '
#                           'educada. Recomendo a todos que queiram conhecer '
#                           'melhor o Rio!',
#               'date': datetime.datetime(2016, 7, 19, 4, 0),
#               'listing_id': '10038496',
#               'reviewer_id': '83235034',
#               'reviewer_name': 'Raphael'},
#              {'_id': '89793633',
#               'comments': 'Excelente anfitrion siempre estuvo pendiente de lo '
#                           'que necesitabamos. El departamento es muy comodo '
#                           'limpio, y muy bien ubicado.',
#               'date': datetime.datetime(2016, 7, 30, 4, 0),
#               'listing_id': '10038496',
#               'reviewer_id': '12345019',
#               'reviewer_name': 'Luis'},
#              {'_id': '96447291',
#               'comments': 'todo fue como estaba en la descripcion, inclusive '
#                           'tanto en toallas como ropa de cama habia de mas '
#                           'para cambiar, muy satisfecho por todo, ubicasion, '
#                           'internet, tv, comodidades y la atencion de ana, que '
#                           'estuvo siempre dispuesta a atendernos, inclusive '
#                           'dejando un celular para urgencias, colmo nuestras '
#                           'espectatibas',
#               'date': datetime.datetime(2016, 8, 22, 4, 0),
#               'listing_id': '10038496',
#               'reviewer_id': '46538654',
#               'reviewer_name': 'Adrian Adolfo'},
#              {'_id': '98707977',
#               'comments': 'The location is perfect, ideal and safe walking '
#                           'distance to Ipanema and Copacabana, including '
#                           'Arpoador just 800 metres away; cheap for Uber to '
#                           'nearby attractions too. I even walked to Leblon '
#                           'from there in under 40 minutes. \n'
#                           '\n'
#                           'The hosts met me up front and helped me with my '
#                           "luggage. They don't speak English, but are very "
#                           'charming and helpful, so we communicated via '
#                           '(Hidden by Airbnb) Translate, using (Hidden by '
#                           'Airbnb) .\n'
#                           '\n'
#                           'The building is slightly older. One day there was '
#                           'no water in the building due to maintenance. The '
#                           'hosts warned me about this, there was nothing they '
#                           'could do and I was prepared. Only issue is that '
#                           'after the water came back, because of the older '
#                           'pipes, it was brown for a little while, just have '
#                           'to let the taps run for several minutes. \n'
#                           '\n'
#                           "The bed isn't the most comfortable for an extended "
#                           'stay (I was there for eight nights), but for short '
#                           "durations it's fine. \n"
#                           '\n'
#                           'There is a washing machine in the apartment, it '
#                           'works great, I dried my clothes by hanging them on '
#                           'chairs, hooks, etc. \n'
#                           '\n'
#                           'The WiFi is strong and reliable. \n'
#                           '\n'
#                           'There is a grocery store and a couple of reasonably '
#                           'priced restaurants on the block, as well as two '
#                           'different banks. Excellent for visitors. A drug '
#                           'store is also available on the next block at the '
#                           'corner. \n'
#                           '\n'
#                           'Overall the inconveniences were small and the '
#                           'positives of this location was great. ',
#               'date': datetime.datetime(2016, 9, 1, 4, 0),
#               'listing_id': '10038496',
#               'reviewer_id': '20095666',
#               'reviewer_name': 'Asif'},
#              {'_id': '105153541',
#               'comments': 'Ana and Jose were wonderful hosts.  They were there '
#                           'when we arrived and showed us everything.  They '
#                           'provided a cell phone for us to use to be in '
#                           'contact with them and were very patient with our '
#                           'lack of technological experience. They were always '
#                           'helpful and accommodating. The apt. was very '
#                           'comfortable and convenient.  I highly recommend '
#                           'this place.  Ana speaks Portuguese and understands '
#                           'Spanish.  If you speak English, she has friends who '
#                           'can help with the translation.',
#               'date': datetime.datetime(2016, 9, 30, 4, 0),
#               'listing_id': '10038496',
#               'reviewer_id': '81173012',
#               'reviewer_name': 'Maureen'},
#              {'_id': '106849380',
#               'comments': 'A localização e excelente com tudo pertinho. Um '
#                           'supermercado ao lado assim como uma padaria e uma '
#                           'lanchonete.  Tinham muito bons restaurantes nas '
#                           'redondezas, inclusive um 24 horas. ',
#               'date': datetime.datetime(2016, 10, 8, 4, 0),
#               'listing_id': '10038496',
#               'reviewer_id': '24470430',
#               'reviewer_name': 'Gracinha Ferreira'},
#              {'_id': '108096704',
#               'comments': 'A anfitriã Ana Valéria é ótima, simpática, super '
#                           'atenciosa, sempre pronta a ajudar. O ap e os '
#                           'utensílios da casa são super limpos, o banho é '
#                           'ótimo e a cama super confortável. A localização é '
#                           'perfeita. Pretendo voltar! ',
#               'date': datetime.datetime(2016, 10, 14, 4, 0),
#               'listing_id': '10038496',
#               'reviewer_id': '94389738',
#               'reviewer_name': 'Mirian'},
#              {'_id': '108662420',
#               'comments': 'Ana Valéria e seu esposo foram extremamente '
#                           'atenciosos e prestativos. Nos receberam '
#                           'extremamente bem. Nos sentimos em casa. O imóvel é '
#                           'realmente o que aparece nas fotos. Muito bem '
#                           'localizado, limpo e funcional. Excelente.',
#               'date': datetime.datetime(2016, 10, 16, 4, 0),
#               'listing_id': '10038496',
#               'reviewer_id': '80330535',
#               'reviewer_name': 'Cesar'},
#              {'_id': '112297076',
#               'comments': 'Ana is an amazing host, she was very accommodating '
#                           'with check-in time and was very easily reached with '
#                           'any problems, even though none transpired. The '
#                           'apartment is about 1.5 blocks away from the beach '
#                           'with banks, restaurants, and a super market within '
#                           'a 10 minute walk. Would highly recommend staying '
#                           'with Ana to anybody wanting to see Rio.   ',
#               'date': datetime.datetime(2016, 11, 5, 4, 0),
#               'listing_id': '10038496',
#               'reviewer_id': '67404285',
#               'reviewer_name': 'Alex'},
#              {'_id': '114177330',
#               'comments': 'Muito boa estadia. A Valéria foi ótima. Super '
#                           'atenciosa e prestativa. Localização é ótima. Acesso '
#                           'fácil às praia de copa e Ipanema. Muitos '
#                           'restaurantes, mercado....\r\n'
#                           'Local limpo. Eu recomendo. ',
#               'date': datetime.datetime(2016, 11, 16, 5, 0),
#               'listing_id': '10038496',
#               'reviewer_id': '1258230',
#               'reviewer_name': 'Gabriela'},
#              {'_id': '116322190',
#               'comments': 'El departamento es genial, aireado, luminoso y muy '
#                           'bien equipado (aunque necesitarìa una mesa) La zona '
#                           'de Copacabana que habìamos elegido, muy conectado '
#                           'con Ipanema, y a pocas cuadras del metro (Gdor. '
#                           'Osorio) \r\n'
#                           'Anfitriones atentos y dispuestos. Nos encantò !!',
#               'date': datetime.datetime(2016, 11, 29, 5, 0),
#               'listing_id': '10038496',
#               'reviewer_id': '45060159',
#               'reviewer_name': 'Ale'},
#              {'_id': '117194294',
#               'comments': 'A anfitriã e seu marido são muito simpáticos , '
#                           'apartamento ideal para um casal , localização '
#                           'fantástica , gostei muito .',
#               'date': datetime.datetime(2016, 12, 5, 5, 0),
#               'listing_id': '10038496',
#               'reviewer_id': '17216383',
#               'reviewer_name': 'Vinícius'},
#              {'_id': '120439457',
#               'comments': 'Este departamento está a una cuadra de la playa, '
#                           'muy bien ubicado, en plena zona comercial y '
#                           'turística de Copacabana.  Al lado de la puerta de '
#                           'entrada había un supermercado con buenos precios y '
#                           'hay muchas tiendas de diferentes tipos '
#                           'alrededor.\r\n'
#                           'El departamento es tal cual se ve en las fotos, muy '
#                           'acogedor y para nada caluroso. Hay un ventilador de '
#                           'techo en el living para la cama que está allí y un '
#                           'ventilador y aire acondicionado para la cama de dos '
#                           'plazas en la habitación. El departamento estaba muy '
#                           'limpio apenas llegamos, con todo en su lugar. '
#                           'Teníamos todo a nuestra disposición, todo bien '
#                           'ordenado.\r\n'
#                           'Valeria nos recibió en la entrada y nos entregó las '
#                           'llaves en mano, nos explicó todo paso a paso del '
#                           'departamento. Su llavero tenía una tarjeta de '
#                           'descuento para el supermercado, ella nos lo prestó '
#                           'y nos sirvió mucho para hacer las compras. Valeria '
#                           'fue de gran ayuda en todo momento. Previo a llegar '
#                           'se contactó conmigo, también durante la estadía por '
#                           'si necesitábamos algo y previo a nuestra partida. '
#                           'Cuando la contactábamos, teníamos respuesta rápida. '
#                           'Eso nos hizo sentir muy cómodos y nos ayudó.\r\n'
#                           'Tanto el departamento como la anfitriona hicieron '
#                           'que tuvieramos una gran estadía en Copacabana.',
#               'date': datetime.datetime(2016, 12, 10, 5, 0),
#               'listing_id': '10038496',
#               'reviewer_id': '27158989',
#               'reviewer_name': 'Pablo'},
#              {'_id': '121218526',
#               'comments': 'Ana Valéria é uma hospedeira muito legal! O '
#                           'apartamento dela é ótimo com todas as coisas do que '
#                           'você precisa. Super confortável e super bem '
#                           'localizado com um mercado ao lado.\n'
#                           'Não tem como reclamar, tudo é perfeito!!! ',
#               'date': datetime.datetime(2016, 12, 15, 5, 0),
#               'listing_id': '10038496',
#               'reviewer_id': '58233964',
#               'reviewer_name': 'Yoan'},
#              {'_id': '123264653',
#               'comments': 'Era como estaba en el anuncio de airbnb',
#               'date': datetime.datetime(2016, 12, 28, 5, 0),
#               'listing_id': '10038496',
#               'reviewer_id': '47326855',
#               'reviewer_name': 'Sebastian'},
#              {'_id': '129536798',
#               'comments': 'Excelente estadía en el departamento de valeria. La '
#                           'ubicación es inmejorable y es muy cómodo. Ella y su '
#                           'esposo muy atentos y dispuestos a ayudar en todo '
#                           'momento. Sin duda lo recomiendo',
#               'date': datetime.datetime(2017, 1, 31, 5, 0),
#               'listing_id': '10038496',
#               'reviewer_id': '38300289',
#               'reviewer_name': 'Carlos German'},
#              {'_id': '132537926',
#               'comments': 'Muito bom o apartamento! Recomendo e pretendo '
#                           '(Website hidden by Airbnb) acho que seria '
#                           'interessante ter no apto uma cadeira de praia e '
#                           'guarda-sol, quem fica por muitos dias hospedado '
#                           'acaba gastando muito com aluguel na praia.Bem '
#                           'localizado, limpo e apto bem dividido.Valeria foi '
#                           'super atenciosa e receptiva, sempre tentando ajudar '
#                           'no que fosse possível.',
#               'date': datetime.datetime(2017, 2, 18, 5, 0),
#               'listing_id': '10038496',
#               'reviewer_id': '97369017',
#               'reviewer_name': 'Hingra'},
#              {'_id': '137610557',
#               'comments': 'Fue realmente un placer alojarnos en el '
#                           'departamento de Copacabana. Perfectamente ubicado, '
#                           'todo funciona impecable, abajo hay un supermercado '
#                           'completo, restaurantes y las playas bien próximas. '
#                           'Y Ana Valeria, la anfitriona, un encanto, siempre '
#                           'conectada para saber sobre nuestras necesidades. '
#                           'Fue un viaje espectacular. EStamos muy agradecidos. '
#                           'Vamos a volver.',
#               'date': datetime.datetime(2017, 3, 16, 4, 0),
#               'listing_id': '10038496',
#               'reviewer_id': '44956140',
#               'reviewer_name': 'Carina'},
#              {'_id': '139244084',
#               'comments': 'Hermoso depto. Cerca de la playa de ipanema . Ana '
#                           'Valeria se preocupo para que nuestra estadia sea '
#                           'buena.Excelente ubicacion, comodo y limpio',
#               'date': datetime.datetime(2017, 3, 24, 4, 0),
#               'listing_id': '10038496',
#               'reviewer_id': '106171754',
#               'reviewer_name': 'Hernan'},
#              {'_id': '140362809',
#               'comments': 'Todo perfecto. El departamento es muy lindo, '
#                           'completo, limpio y todo funciona perfectamente. '
#                           'Tanto Ana Valeria como José siempre atentos y en '
#                           'comunicación. Super recomendable!',
#               'date': datetime.datetime(2017, 3, 29, 4, 0),
#               'listing_id': '10038496',
#               'reviewer_id': '94973779',
#               'reviewer_name': 'Priscila'},
#              {'_id': '141723867',
#               'comments': 'Excelente ubicación y departamento muy hermoso. '
#                           'Valeria fue muy amable y comunicativa. Estuvo en '
#                           'cada detalle y ademas nos facilitó un lugar para '
#                           'poder dejar nuestras valijas luego del check out, '
#                           'ya que viajábamos tarde. Muy recomendable! '
#                           'Seguramente volveremos pronto.',
#               'date': datetime.datetime(2017, 4, 4, 4, 0),
#               'listing_id': '10038496',
#               'reviewer_id': '114863139',
#               'reviewer_name': 'Natalia'},
#              {'_id': '142801153',
#               'comments': 'Um bom apartamento, pertinho da pedra do Arpoardor '
#                           'e a 1 quadra da praia de Copacabana. Ônibus fácil '
#                           'para todo o canto, supermercado embaixo do prédio. '
#                           'Apartamento exatamente igual ao descrito no '
#                           'anúncio.',
#               'date': datetime.datetime(2017, 4, 9, 4, 0),
#               'listing_id': '10038496',
#               'reviewer_id': '12398467',
#               'reviewer_name': 'Louise'},
#              {'_id': '144728300',
#               'comments': 'Apartamento bem equipado, localização excelente '
#                           '(tem tudo perto) e anfitriã muito disponível para '
#                           'as informações necessárias. Recomendo demais!',
#               'date': datetime.datetime(2017, 4, 16, 4, 0),
#               'listing_id': '10038496',
#               'reviewer_id': '22762689',
#               'reviewer_name': 'Achilles'},
#              {'_id': '148736479',
#               'comments': 'Super appartement, idéalement situé à deux pas de '
#                           "Copacabana, 10 minutes d'Ipanéma et du métro. "
#                           "L'appartement est fonctionnel, propre, agréable, "
#                           "sécurisé. En bas de l'immeuble, il y a un petit "
#                           'centre commercial bien pratique et une délicieuse '
#                           'boulangerie. Nous sommes restés 15 jours et avons '
#                           'énormément visité. Les plages à proximité sont '
#                           'vivantes. Enfin, merci à Anna Valéria pour nos '
#                           'échanges et ses attentions. Son ami Fernando nous a '
#                           "fait le transfert de l'appartement à l'aéroport. Il "
#                           'est adorable. Beaucoup de choses à découvrir à Rio. '
#                           'Nous avons fait un très beau voyage.',
#               'date': datetime.datetime(2017, 5, 1, 4, 0),
#               'listing_id': '10038496',
#               'reviewer_id': '14703886',
#               'reviewer_name': 'Christophe'},
#              {'_id': '156164871',
#               'comments': 'Super Recomendo! O apto é impecável, funcional, '
#                           'aconchegante e o melhor numa localização '
#                           'privilegiada! Sem contar o atendimento PRIME da Ana '
#                           'Valéria! Excelente!',
#               'date': datetime.datetime(2017, 5, 29, 4, 0),
#               'listing_id': '10038496',
#               'reviewer_id': '121580398',
#               'reviewer_name': 'Ricardo'},
#              {'_id': '158815208',
#               'comments': 'Ana, fue un maravilloso viaje, sin la comodidad y '
#                           'buena ubicación del departamento no hubiese sido '
#                           'igual.  \n'
#                           'Muito obrigado!',
#               'date': datetime.datetime(2017, 6, 8, 4, 0),
#               'listing_id': '10038496',
#               'reviewer_id': '119276115',
#               'reviewer_name': 'Sergio'},
#              {'_id': '167658254',
#               'comments': 'If you want something close to the beach and to '
#                           'live like a carioca this is the spot. Close to '
#                           'metro, ipanema, copa, supermarket, paderia, tudo! '
#                           'Great communication. Thank you for the perfect '
#                           'place Ana! ',
#               'date': datetime.datetime(2017, 7, 7, 4, 0),
#               'listing_id': '10038496',
#               'reviewer_id': '16069925',
#               'reviewer_name': 'Leah'},
#              {'_id': '172657826',
#               'comments': 'La verdad es que fue todo muy lindo!!! Ana Valeria '
#                           'tiene mucha buena onda, se preocupo porque siempre '
#                           'este todo bien, el departamento es muy amplio, '
#                           'cómodo, tiene todo lo que se precisa, muy limpio y '
#                           'ordenado, todo funciona a la perfección. La '
#                           'ubicación es espectacular, cerca de la playa y a '
#                           'minutos de Ipanema. Ana Valeria una genia, una '
#                           'persona muy cálida. Muy recomendable!!!!!',
#               'date': datetime.datetime(2017, 7, 21, 4, 0),
#               'listing_id': '10038496',
#               'reviewer_id': '131973196',
#               'reviewer_name': 'Bel'},
#              {'_id': '175339972',
#               'comments': 'Muy bien ubicado, Valeria fue muy amable y '
#                           'atenta. \n'
#                           'Sin duda recomindo su departamento.',
#               'date': datetime.datetime(2017, 7, 28, 4, 0),
#               'listing_id': '10038496',
#               'reviewer_id': '40998565',
#               'reviewer_name': 'Talia'},
#              {'_id': '193197117',
#               'comments': 'Excelente localização e a Valeria uma excelente '
#                           'anfitriã, super preocupada em nos deixar muito a '
#                           'vontade. O apartamento tem uma energia muito boa.',
#               'date': datetime.datetime(2017, 9, 12, 4, 0),
#               'listing_id': '10038496',
#               'reviewer_id': '110978677',
#               'reviewer_name': 'Fernanda'},
#              {'_id': '197318690',
#               'comments': 'Ideal para um casal, com ótima localização próximo '
#                           'a supermercado, restaurantes e bancos. Valéria é '
#                           'super receptiva e nos recebeu muito bem. Ficaria '
#                           'hospedada aqui novamente. :)',
#               'date': datetime.datetime(2017, 9, 25, 4, 0),
#               'listing_id': '10038496',
#               'reviewer_id': '40645058',
#               'reviewer_name': 'Mariana'},
#              {'_id': '206271447',
#               'comments': 'La zona es la mejor, cerca de pla 2 mejores playas '
#                           'de Rio, el departamento es bastante comodo y es tal '
#                           'como lo muestran en fotos, Ana Valeria y su esposo '
#                           'son extremadamente amables y serviciales, nos '
#                           'ayudaron mucho. Un pequeño punto a mejorar son los '
#                           'canales de Tv que solo son unos 6 y  solo un par de '
#                           'entretenimiento.',
#               'date': datetime.datetime(2017, 10, 24, 4, 0),
#               'listing_id': '10038496',
#               'reviewer_id': '70411464',
#               'reviewer_name': 'Edson Gary'},
#              {'_id': '209485024',
#               'comments': 'Ana Valéria é muito prestativa e as fotos do '
#                           'apartamento refletem realmente como é. Localização '
#                           'excelente. \n'
#                           'Recomendo',
#               'date': datetime.datetime(2017, 11, 5, 4, 0),
#               'listing_id': '10038496',
#               'reviewer_id': '42865577',
#               'reviewer_name': 'Adalton'},
#              {'_id': '216576249',
#               'comments': "Great location lot of amenities we're close and is "
#                           'easy to work with I would stay there again',
#               'date': datetime.datetime(2017, 12, 4, 5, 0),
#               'listing_id': '10038496',
#               'reviewer_id': '149141767',
#               'reviewer_name': 'Danny'},
#              {'_id': '218212792',
#               'comments': 'Ótima localização, tudo a mão, excelente '
#                           'atendimento, preço justo, lugar amplo e '
#                           'aconchegante. Recomendo.',
#               'date': datetime.datetime(2017, 12, 11, 5, 0),
#               'listing_id': '10038496',
#               'reviewer_id': '155795023',
#               'reviewer_name': 'Luís Fernando'},
#              {'_id': '220059333',
#               'comments': 'Nice location. Great host . I do recoment.',
#               'date': datetime.datetime(2017, 12, 20, 5, 0),
#               'listing_id': '10038496',
#               'reviewer_id': '22443804',
#               'reviewer_name': 'Douglas'},
#              {'_id': '223023774',
#               'comments': 'Nice place and location!\nThanks!',
#               'date': datetime.datetime(2017, 12, 31, 5, 0),
#               'listing_id': '10038496',
#               'reviewer_id': '77730304',
#               'reviewer_name': 'Facundo'},
#              {'_id': '225106904',
#               'comments': 'O apto é super bem localizado, funcional e limpo. O '
#                           'prédio é antigo (como todos no bairro de '
#                           'Copacabana) mas o apto em si é muito bom. Apesar de '
#                           'estar em avenida super movimentada, o barulho '
#                           'externo foi menor do que eu esperava. Dormi muito '
#                           'bem. Eu e minha familia gostamos muito da nossa '
#                           'estadia nele. Tem Mercado, bancos, padaria na mesma '
#                           'quadra e fica 1 quadra da praia de Copacabana.',
#               'date': datetime.datetime(2018, 1, 5, 5, 0),
#               'listing_id': '10038496',
#               'reviewer_id': '133210672',
#               'reviewer_name': 'Natasha'},
#              {'_id': '226386493',
#               'comments': 'Fue una estadía increíble! Ana Valeria fue muy '
#                           'atenta y el departamento impecable, súper bien '
#                           'equipado y excelente ubicación. Mejor que en las '
#                           'fotos!  Estábamos a pocos pasos de las playas de '
#                           'Copacabana e Ipanema. El entorno súper seguro, con '
#                           'perfecto acceso a compras y restorantes. Quedamos '
#                           'felices con nuestra visita a Río, totalmente '
#                           'recomendado',
#               'date': datetime.datetime(2018, 1, 10, 5, 0),
#               'listing_id': '10038496',
#               'reviewer_id': '45908423',
#               'reviewer_name': 'Florencia'},
#              {'_id': '230187055',
#               'comments': 'Hermoso departamento.. el aire acondicionado y '
#                           'ventiladores excelentes. Departamento muy limpio, '
#                           'contaba con todo lo necesario: juguera, tostadora, '
#                           'lavadora, zona para tender ropa, plancha... todo. '
#                           'El sector... el mejor.. a una cuadra de la playa, '
#                           'al lado un mercado para comprar frutas..  muy cerca '
#                           'del supermercado... farmacias, banco, la playa '
#                           'hermosa... muy tranquilo, no tuve ningún problema, '
#                           'muchos turistas.. todo muy iluminado. A dos cuadras '
#                           'está el hotel Atlantis... donde compré 3 tours a : '
#                           'Angra do Reis/Isla Grande, Búzios y uno a Cabo do '
#                           'Reis... todos excelentes 200 reales por persona. '
#                           'Recomiendo un restaurante a 2 cuadras del depto de '
#                           'Valeria se llama Eclipse... ricas pizas a 12,5 '
#                           'reales... hamburguesas con papa a 18 reales... '
#                           'carnes con agregados(picaña) a 33 reales... muy '
#                           'rico y buen precio. Valeria una excelente '
#                           'anfitriona, muy confiable. Uber funciona sin '
#                           'problema. Lo pasamos increíble.',
#               'date': datetime.datetime(2018, 1, 27, 5, 0),
#               'listing_id': '10038496',
#               'reviewer_id': '106652946',
#               'reviewer_name': 'Milena'},
#              {'_id': '237316959',
#               'comments': 'El dpto es como en las fotos, Ana Valeria super '
#                           'amable, nos ayudo con sugerencias turisticas . Esta '
#                           'bien super bien ubicado, entre copacabana e '
#                           'ipanema.',
#               'date': datetime.datetime(2018, 2, 22, 5, 0),
#               'listing_id': '10038496',
#               'reviewer_id': '81957168',
#               'reviewer_name': 'Valeria'},
#              {'_id': '239373208',
#               'comments': 'L appartement est très bien situé, à 2 pas de la '
#                           'plage de Copacabana et tout près d Ipanema, dans un '
#                           'quartier sans problème \n'
#                           'Il y a juste en bas un petit supermarché très  bien '
#                           'approvisionné pour cuisiner\n'
#                           'Nos hôtes nous ont très bien accueilli et ont été '
#                           'très disponibles pour communiquer pendant tout le '
#                           'séjour !',
#               'date': datetime.datetime(2018, 3, 1, 5, 0),
#               'listing_id': '10038496',
#               'reviewer_id': '67840133',
#               'reviewer_name': 'Cecile'},
#              {'_id': '242202709',
#               'comments': 'A Ana Valéria é com ctz uma superanfitriã, nos '
#                           'recebeu presencialmente antes do horário de checkin '
#                           'em virtude da acomodação das bagagens e o fez com '
#                           'muita simpatia e alegria. Foi solicita em tudo q '
#                           'foi perguntado, sempre de forma rápida e prática. '
#                           'Na hora do checkout tbm foi flexível em nos '
#                           'auxiliar para acomodação da bagagem à espera do '
#                           'horário do vôo. O ap é muito limpo e aconchegante, '
#                           'com vários utensílios domésticos q facilitam a vida '
#                           'do turista para q economize em sua estadia. A '
#                           'localização é privilegiada, a uma quadra da praia '
#                           'de Copacabana e a 5 min caminhando da praia do '
#                           'Arpoador, nossa preferida, que aliás, é bom '
#                           'ressaltar, estava muito bem policiada durante minha '
#                           'estadia de 7 dias no Rio. Superecomendo o ap de Ana '
#                           'Valéria e com ctz voltarei em breve.',
#               'date': datetime.datetime(2018, 3, 11, 5, 0),
#               'listing_id': '10038496',
#               'reviewer_id': '94207939',
#               'reviewer_name': 'Júnior'},
#              {'_id': '243563030',
#               'comments': 'Local super bem localizado, amplo, perto de todas '
#                           'as comodidades possíveis...praia fica bem '
#                           'próximo...',
#               'date': datetime.datetime(2018, 3, 16, 4, 0),
#               'listing_id': '10038496',
#               'reviewer_id': '105008685',
#               'reviewer_name': 'Ernani'},
#              {'_id': '246019537',
#               'comments': 'O apartamento é bem localizado,  limpo e a Ana '
#                           'Valéria é muito atenciosa. \n'
#                           'Voltaria com certeza. ',
#               'date': datetime.datetime(2018, 3, 24, 4, 0),
#               'listing_id': '10038496',
#               'reviewer_id': '56758262',
#               'reviewer_name': 'Fatima'},
#              {'_id': '250030545',
#               'comments': 'Me hospedei com mais dois amigos no apto da Ana! '
#                           'Foi tudo perfeito! Ela nos ajudou com tudo que '
#                           'precisávamos!\n'
#                           'O apto está em boas condições, tinha tudo que '
#                           'precisávamos, desde utensílios de cozinha até '
#                           'roupas de cama e banho.\n'
#                           'A localização é ótima! Uma quadra do posto 6 em '
#                           'Copacabana e 10min de Ipanema! Possui supermercado, '
#                           'padaria e farmácias na porta do edifício! \n'
#                           'Tivemos uma ótima estada! Obrigado Ana!',
#               'date': datetime.datetime(2018, 4, 3, 4, 0),
#               'listing_id': '10038496',
#               'reviewer_id': '49892754',
#               'reviewer_name': 'Victor'},
#              {'_id': '252180209',
#               'comments': 'Espaço muito bem localizado, região tranquila e '
#                           '(Website hidden by Airbnb) certeza voltarei a me '
#                           'hospedar lá! Os proprietários são de fácil '
#                           'comunicação e são prestativos.',
#               'date': datetime.datetime(2018, 4, 9, 4, 0),
#               'listing_id': '10038496',
#               'reviewer_id': '165668545',
#               'reviewer_name': 'João Paulo Anselmo'},
#              {'_id': '255781870',
#               'comments': 'Nos encanto Río! \n'
#                           'AnaValeria súper amable y encantadora.\n'
#                           'El departamento muy cómodo y muy lindo, tal cual '
#                           'las fotos.\n'
#                           'Todo perfecto!\n'
#                           'Esperamos volver!\n'
#                           'Gracias!!!',
#               'date': datetime.datetime(2018, 4, 21, 4, 0),
#               'listing_id': '10038496',
#               'reviewer_id': '170949772',
#               'reviewer_name': 'Guido Jorge'},
#              {'_id': '261993239',
#               'comments': 'Ana Valeria a été super réactive dès notre '
#                           'réservation. Elle était là pour nous accueillir et '
#                           'nous montrer l appartement. Celui-ci était bien '
#                           'équipé notamment la cuisine, top comme ça nous '
#                           'avons pu preparer les petits plats pour bébé. L '
#                           'emplacement est idéal pour qui souhaite profiter d '
#                           'Ipanema e Copacabana. Restaurant et bars à '
#                           'proximité. Nous avons passé 4 jours à Rio très '
#                           'sympa.',
#               'date': datetime.datetime(2018, 5, 7, 4, 0),
#               'listing_id': '10038496',
#               'reviewer_id': '12426799',
#               'reviewer_name': 'Estelle & Jean'},
#              {'_id': '264999793',
#               'comments': 'Excelente departamento y muy bien ubicado entre las '
#                           'playas de Copacabana (1 cuadra) e Ipanema (5 '
#                           'cuadras). Tiene todas las comodidades para tener '
#                           'una excelente estancia en una ciudad como Río de '
#                           'Janeiro! Hay un supermercado justo al lado del '
#                           'edificio, muy cómodo para abastecerse a toda hora, '
#                           'y bancos enfrente en la misma cuadra. Ya me he '
#                           'alojado 2 veces aquí y volvería a hacerlo! La '
#                           'hospitalidad de Valeria fue excelente ambas veces, '
#                           'tanto al ingresar como al salir del departamento.',
#               'date': datetime.datetime(2018, 5, 15, 4, 0),
#               'listing_id': '10038496',
#               'reviewer_id': '56705324',
#               'reviewer_name': 'Daniel'},
#              {'_id': '291815191',
#               'comments': 'm legal',
#               'date': datetime.datetime(2018, 7, 16, 4, 0),
#               'listing_id': '10038496',
#               'reviewer_id': '39723696',
#               'reviewer_name': 'David'},
#              {'_id': '297817291',
#               'comments': 'Ana was a fantastic host. The apartment was very '
#                           'clean and comfortable. The location was perfect.  '
#                           'We had a great trip to Rio. I highly recommend.',
#               'date': datetime.datetime(2018, 7, 28, 4, 0),
#               'listing_id': '10038496',
#               'reviewer_id': '5881328',
#               'reviewer_name': 'Sed And Luciana'},
#              {'_id': '303959226',
#               'comments': 'Excelente alojamiento con ubicación ideal para '
#                           'conocer río, supermercado a 10 metros, equipado con '
#                           'todo lo necesario y muy buena atención de parte de '
#                           'Ana Valeria. Muy recomendable\n',
#               'date': datetime.datetime(2018, 8, 8, 4, 0),
#               'listing_id': '10038496',
#               'reviewer_id': '204292479',
#               'reviewer_name': 'Miguel'},
#              {'_id': '307011277',
#               'comments': 'Excelente apartamento super limpo, arejado e '
#                           'espaçoso. A anfitriã dispensa comentários, '
#                           'excelente pessoa, sempre disposta a ajudar, super '
#                           'prestativa e um amor de (Website hidden by Airbnb) '
#                           'certeza iremos retornar é super recomendo',
#               'date': datetime.datetime(2018, 8, 13, 4, 0),
#               'listing_id': '10038496',
#               'reviewer_id': '104924380',
#               'reviewer_name': 'Guaracy'},
#              {'_id': '315749969',
#               'comments': 'A minha estadia no apartamento da Ana Valéria foi '
#                           'incrível! O apartamento é exatamente como mostram '
#                           'as fotos, é muito confortável e acomoda '
#                           'tranquilamente até quatro pessoas! Tem tudo o que é '
#                           'preciso para uma boa estadia, como utensílios de '
#                           'cozinha e roupas de cama e banho! Os banheiros '
#                           'estavam extremamente limpos, a recepção e a '
#                           'comunicação foi ótima! Além disso, é preciso '
#                           'destacar a localização, bem próxima às praias de '
#                           'Copacabana e Ipanema, e de estar no mesmo '
#                           'quarteirão de lanchonete, padaria, restaurante, '
#                           'supermercado, farmácia e bancos! Super indico e com '
#                           'certeza voltaria a me hospedar lá.',
#               'date': datetime.datetime(2018, 8, 29, 4, 0),
#               'listing_id': '10038496',
#               'reviewer_id': '204842220',
#               'reviewer_name': 'José Vângelo'},
#              {'_id': '335976265',
#               'comments': 'Wir haben zu dritt 3 Nächte im Apartment von Ana '
#                           'Valeria verbracht. Die Kommunikation hat sehr gut '
#                           'funktioniert und wir konnten das Apartment rasch '
#                           'finden. Wir wurden sehr herzlich begrüsst! Der '
#                           'Standort ist perfekt, da der Strand von Copacabana '
#                           '(ca.3 Min.) so wie die Ipanema (ca.10Min) zu Fuss '
#                           'zu erreiche sind. Zudem ist ein Supermarkt direkt '
#                           'neben dem Eingang! Wir haben uns auch Nachts sicher '
#                           'gefühlt und würden die Unterkunft herzlichst weiter '
#                           'empfehlen.',
#               'date': datetime.datetime(2018, 10, 13, 4, 0),
#               'listing_id': '10038496',
#               'reviewer_id': '23072673',
#               'reviewer_name': 'Laura'},
#              {'_id': '338815440',
#               'comments': 'Appartement propre , confortable et parfaitement '
#                           'situé. Valeria est très réactive, j’ai eu un soucis '
#                           'avec le pommeau de douche qui a cassé le soir et le '
#                           'lendemain matin c’était changé. Je recommande sans '
#                           'aucun doute.',
#               'date': datetime.datetime(2018, 10, 20, 4, 0),
#               'listing_id': '10038496',
#               'reviewer_id': '205528285',
#               'reviewer_name': 'Fabien'},
#              {'_id': '341679758',
#               'comments': 'Maravilhosa estadia! Ap muito aconchegante, bem '
#                           'localizado, perto da praia, comércios, restaurantes '
#                           'e metrô. Ana Valéria é um amor!',
#               'date': datetime.datetime(2018, 10, 27, 4, 0),
#               'listing_id': '10038496',
#               'reviewer_id': '173489896',
#               'reviewer_name': 'Amoriara'},
#              {'_id': '346986452',
#               'comments': 'Regular...',
#               'date': datetime.datetime(2018, 11, 10, 5, 0),
#               'listing_id': '10038496',
#               'reviewer_id': '222299471',
#               'reviewer_name': 'Juan'},
#              {'_id': '354036835',
#               'comments': 'O apartamento fica a menos de 2 quadras da praia e '
#                           'do Forte de Copacabana (que é um lugar que vale a '
#                           'pena visitar). Um pouquinho depois, caminhando, já '
#                           'se chega no Arpoador. Na mesma quadra do apto tem '
#                           'supermercado, padaria e outros comércios. Ana '
#                           'Valéria foi sempre simpática e nos entregou o apto '
#                           'limpo e com todos os itens que poderíamos precisar, '
#                           'inclusive duas cadeiras de praia. Excelente! '
#                           'Recomendamos!',
#               'date': datetime.datetime(2018, 11, 30, 5, 0),
#               'listing_id': '10038496',
#               'reviewer_id': '167966847',
#               'reviewer_name': 'Cristiane'},
#              {'_id': '357036814',
#               'comments': 'Com certeza recomendo o local, excelente recepçao e '
#                           'disponibilidade. Valeria sempre foi atenciosa e '
#                           'preocupada c nosso bem estar. Espaço amplo e muito '
#                           'bem localizado. Espero voltar mais vezes.',
#               'date': datetime.datetime(2018, 12, 9, 5, 0),
#               'listing_id': '10038496',
#               'reviewer_id': '153445227',
#               'reviewer_name': 'Marcia'},
#              {'_id': '368187046',
#               'comments': 'This is the second time I’ve stayed with Ana '
#                           'Valeria. Both stays were about a month. Ana Valeria '
#                           'is a sweet and considerate host. \n'
#                           '\n'
#                           'I would not call the apartment luxurious, but it '
#                           'has everything you need and it’s clean. A small '
#                           'kitchen, and laundry is a must for me. If you’re '
#                           'like me, and you love Rio, and go to the beach '
#                           'everyday, there is no better location. I can hop on '
#                           'a skateboard and get to Leme or leblon, no prob. \n'
#                           '\n'
#                           'I won’t say more, so when I want to book again it '
#                           'will be available!!\n'
#                           '\n'
#                           'Thank you Ana Valeria. Beijão, amiga.',
#               'date': datetime.datetime(2019, 1, 6, 5, 0),
#               'listing_id': '10038496',
#               'reviewer_id': '16069925',
#               'reviewer_name': 'Leah'},
#              {'_id': '402138734',
#               'comments': 'Incrível hospitalidade, fizemos o check-in antes do '
#                           'horário combinado! O apartamento é super legal, '
#                           'extremamente bem localizado. Panificadoras, '
#                           'mercados, restaurantes, bancos, metro, praias e '
#                           'diversas coisas ao alcance. Ar condicionado antigo '
#                           'mas funciona bem e é limpo.',
#               'date': datetime.datetime(2019, 1, 17, 5, 0),
#               'listing_id': '10038496',
#               'reviewer_id': '189203898',
#               'reviewer_name': 'Murylo'},
#              {'_id': '403178477',
#               'comments': 'Tudo conforme anunciado. Recomendo e voltaria.',
#               'date': datetime.datetime(2019, 1, 20, 5, 0),
#               'listing_id': '10038496',
#               'reviewer_id': '21231279',
#               'reviewer_name': 'Pedro'},
#              {'_id': '404802128',
#               'comments': 'O apartamento da Ana Valéria é ótimo em todas as '
#                           'questões... a localização é fantástica. A Ana '
#                           'Valéria é uma excelente anfitriã, nos recebeu muito '
#                           'bem com alguns mimos extras. Adorei meus dias no '
#                           'apartamento dela!',
#               'date': datetime.datetime(2019, 1, 25, 5, 0),
#               'listing_id': '10038496',
#               'reviewer_id': '193776680',
#               'reviewer_name': 'Claudineia'},
#              {'_id': '406107824',
#               'comments': 'Tudo perfeito! O apto é muito bem localizado e '
#                           'atendeu perfeitamente minha família. Anfitriã '
#                           'prestativa e atenciosa.',
#               'date': datetime.datetime(2019, 1, 28, 5, 0),
#               'listing_id': '10038496',
#               'reviewer_id': '144134435',
#               'reviewer_name': 'Alessandra'}],
#  'room_type': 'Entire home/apt',
#  'security_deposit': Decimal128('600.00'),
#  'space': 'The apartment has a living room, wash room, suite and an American '
#           "kitchen. The bedroom has a double bed and there's a bunk bed in the "
#           'living room. It is very well located, in the Copacabana beach block '
#           'and just a few blocks from Arpoador and Ipanema. You can walk to '
#           'any of those beaches. It has internet wifi, tv, air conditioning in '
#           'the bedroom, ceiling fans in the living room and the bedroom and an '
#           'equipped kitchen with cooker, fridge, washing machine, microwave '
#           'and utensils. Ease of public transportation, banks, markets and '
#           'restaurants.',
#  'summary': 'The Apartment has a living room, toilet, bedroom (suite) and '
#             'American kitchen. Well located, on the Copacabana beach block a '
#             '05 Min. walk from Ipanema beach (Arpoador). Internet wifi, cable '
#             'tv, air conditioning in the bedroom, ceiling fans in the bedroom '
#             'and living room, kitchen with microwave, cooker, Blender, dishes, '
#             'cutlery and service area with fridge, washing machine, '
#             'clothesline for drying clothes and closet with several utensils '
#             'for use.  The property boasts 45 m2.',
#  'transit': 'On the street there is plenty of transport and the subway station '
#             'is nearby (06 blocks). To get to the Christ the Redeemer Statue '
#             'there are the options of Metro, bus (at the door) or taxi and the '
#             'Sugar Loaf (pão de açúcar), bus (at the door), cab, all very '
#             'close.'}

# %%
#리뷰숫자가 5개이상 되는걸 뽑아보자. ($match $expr 사용 )

for i in db.airbnb.aggregate([{"$match":{"reviews":{"$exists":True}}},
                              {"$match":{"$expr":{"$gt": [{"$size":"$reviews"},5]}}},
                              {"$limit":1}]):
    pprint(i)
# Out:
# {'_id': '10038496',
#  'access': 'todo o espaço.',
#  'accommodates': 4,
#  'address': {'country': 'Brazil',
#              'country_code': 'BR',
#              'government_area': 'Copacabana',
#              'location': {'coordinates': [-43.190849194463404,
#                                           -22.984339360067814],
#                           'is_location_exact': False,
#                           'type': 'Point'},
#              'market': 'Rio De Janeiro',
#              'street': 'Rio de Janeiro, Rio de Janeiro, Brazil',
#              'suburb': 'Copacabana'},
#  'amenities': ['TV',
#                'Cable TV',
#                'Internet',
#                'Wifi',
#                'Air conditioning',
#                'Kitchen',
#                'Paid parking off premises',
#                'Smoking allowed',
#                'Doorman',
#                'Elevator',
#                'Buzzer/wireless intercom',
#                'Family/kid friendly',
#                'Washer',
#                'Fire extinguisher',
#                'Essentials',
#                'Hangers',
#                'Hair dryer',
#                'Iron',
#                'Laptop friendly workspace',
#                'Hot water',
#                'Bed linens',
#                'Extra pillows and blankets',
#                'Microwave',
#                'Coffee maker',
#                'Refrigerator',
#                'Dishes and silverware',
#                'Oven',
#                'Stove',
#                'Long term stays allowed',
#                'Wide hallway clearance',
#                'Host greets you'],
#  'availability': {'availability_30': 7,
#                   'availability_365': 118,
#                   'availability_60': 19,
#                   'availability_90': 33},
#  'bathrooms': Decimal128('2.0'),
#  'bed_type': 'Real Bed',
#  'bedrooms': 1,
#  'beds': 3,
#  'calendar_last_scraped': datetime.datetime(2019, 2, 11, 5, 0),
#  'cancellation_policy': 'strict_14_with_grace_period',
#  'cleaning_fee': Decimal128('150.00'),
#  'description': 'The Apartment has a living room, toilet, bedroom (suite) and '
#                 'American kitchen. Well located, on the Copacabana beach block '
#                 'a 05 Min. walk from Ipanema beach (Arpoador). Internet wifi, '
#                 'cable tv, air conditioning in the bedroom, ceiling fans in '
#                 'the bedroom and living room, kitchen with microwave, cooker, '
#                 'Blender, dishes, cutlery and service area with fridge, '
#                 'washing machine, clothesline for drying clothes and closet '
#                 'with several utensils for use.  The property boasts 45 m2. '
#                 'The apartment has a living room, wash room, suite and an '
#                 "American kitchen. The bedroom has a double bed and there's a "
#                 'bunk bed in the living room. It is very well located, in the '
#                 'Copacabana beach block and just a few blocks from Arpoador '
#                 'and Ipanema. You can walk to any of those beaches. It has '
#                 'internet wifi, tv, air conditioning in the bedroom, ceiling '
#                 'fans in the living room and the bedroom and an equipped '
#                 'kitchen with cooker, fridge, washing machine, microwave and '
#                 'utensils. Ease of public transportation, banks, mar',
#  'extra_people': Decimal128('40.00'),
#  'first_review': datetime.datetime(2016, 1, 18, 5, 0),
#  'guests_included': Decimal128('3'),
#  'host': {'host_about': 'Professora de Educação Física formada pela '
#                         'universidade Gama Filho.',
#           'host_has_profile_pic': True,
#           'host_id': '51530266',
#           'host_identity_verified': True,
#           'host_is_superhost': True,
#           'host_listings_count': 2,
#           'host_location': 'Rio de Janeiro, State of Rio de Janeiro, Brazil',
#           'host_name': 'Ana Valéria',
#           'host_neighbourhood': 'Copacabana',
#           'host_picture_url': 'https://a0.muscache.com/im/pictures/8c7bb5fe-7b6d-4d03-a465-aae8971a87a0.jpg?aki_policy=profile_x_medium',
#           'host_response_rate': 100,
#           'host_response_time': 'within an hour',
#           'host_thumbnail_url': 'https://a0.muscache.com/im/pictures/8c7bb5fe-7b6d-4d03-a465-aae8971a87a0.jpg?aki_policy=profile_small',
#           'host_total_listings_count': 2,
#           'host_url': 'https://www.airbnb.com/users/show/51530266',
#           'host_verifications': ['email',
#                                  'phone',
#                                  'reviews',
#                                  'jumio',
#                                  'government_id']},
#  'house_rules': 'Entreguem o imóvel conforme receberam e respeitem as regras '
#                 'do condomínio para não serem incomodados.  Não danificar os '
#                 'utensílios e tudo que se refere as boas condições referentes '
#                 'ao mesmo . Não fazer barulho após às 22:00  até às 8:00. Usar '
#                 'entrada de serviço se estiver molhado voltando da praia.',
#  'images': {'medium_url': '',
#             'picture_url': 'https://a0.muscache.com/im/pictures/159d489e-62ad-44c4-80a0-fab2a8f3b455.jpg?aki_policy=large',
#             'thumbnail_url': '',
#             'xl_picture_url': ''},
#  'interaction': 'Contact telephone numbers if needed: Valeria ((PHONE NUMBER '
#                 'HIDDEN) (URL HIDDEN) ((PHONE NUMBER HIDDEN) cell phone (URL '
#                 'HIDDEN) (021) mobile/(PHONE NUMBER HIDDEN) José (URL '
#                 'HIDDEN)Concierge support; Fernando (caretaker boss) business '
#                 'hours.',
#  'last_review': datetime.datetime(2019, 1, 28, 5, 0),
#  'last_scraped': datetime.datetime(2019, 2, 11, 5, 0),
#  'listing_url': 'https://www.airbnb.com/rooms/10038496',
#  'maximum_nights': '75',
#  'minimum_nights': '3',
#  'name': 'Copacabana Apartment Posto 6',
#  'neighborhood_overview': 'Copacabana in the South zone is the district that '
#                           'offers the greatest number of options for tourists, '
#                           'transport, restaurants, banks, pharmacies and '
#                           'commerce in general are in abundance in all the '
#                           'blocks of the neighborhood.',
#  'notes': '',
#  'number_of_reviews': 70,
#  'price': Decimal128('119.00'),
#  'property_type': 'Apartment',
#  'review_scores': {'review_scores_accuracy': 10,
#                    'review_scores_checkin': 10,
#                    'review_scores_cleanliness': 10,
#                    'review_scores_communication': 10,
#                    'review_scores_location': 10,
#                    'review_scores_rating': 98,
#                    'review_scores_value': 10},
#  'reviews': [{'_id': '60037020',
#               'comments': 'Bom, foi uma experiencia incrível com a Ana e seu '
#                           'apartamento. Primeiramente ressalto a grande '
#                           'hospitalidade e prestatividade da anfitriã, na '
#                           'residência não tinha ferro de passar roupa '
#                           'solicitei e a mesma imediatamente comprou, deixou '
#                           'uns brindes na geladeira como água e cerveja, '
#                           'excelente tratamento.\r\n'
#                           'Sobre o apartamento, muito bem localizado e bem '
#                           'arrumado, camas bem confortáveis e tudo funcionando '
#                           'corretamente.\r\n'
#                           'Obrigado Ana, espero poder me hospedar em breve no '
#                           'seu ap.\r\n'
#                           '\r\n'
#                           'abraços',
#               'date': datetime.datetime(2016, 1, 18, 5, 0),
#               'listing_id': '10038496',
#               'reviewer_id': '44949795',
#               'reviewer_name': 'Valim'},
#              {'_id': '62079672',
#               'comments': 'Perfect location for Rio,very secure & very close '
#                           'to Copacabana and Ipanema beaches, the apartment is '
#                           'clean and very comfortable, all the equipment are '
#                           'included.\r\n'
#                           'The host Ana its so nice, it was always available '
#                           'for us to help us for anything in the city, I would '
#                           'definitely recommend her place and i will stay '
#                           'there again if I have the chance !',
#               'date': datetime.datetime(2016, 2, 11, 5, 0),
#               'listing_id': '10038496',
#               'reviewer_id': '47057044',
#               'reviewer_name': 'Nabil'},
#              {'_id': '63557342',
#               'comments': "I had an amazing time at Valeria's flat. \n"
#                           'The flat is great!!! Very very clean.\n'
#                           'The location is perfect!\n'
#                           'And on top of everything Valeria and her husband '
#                           'are fantastic host.\n'
#                           'I highly recommend it.',
#               'date': datetime.datetime(2016, 2, 24, 5, 0),
#               'listing_id': '10038496',
#               'reviewer_id': '669357',
#               'reviewer_name': 'Davi'},
#              {'_id': '68976444',
#               'comments': 'Ana y José hicieron que nos sintiéramos en casa '
#                           'desde el primer momento (nos recibieron con '
#                           'cervecitas fresquitas), siempre pendientes de lo '
#                           'que podíamos necesitar y muy predispuestos para dar '
#                           'consejos y ayuda. Muy preocupados por que el '
#                           'apartamento estuviera en perfectas condiciones.\r\n'
#                           'El Departamento es excelente, muy bien ubicado, ya '
#                           'que abajo hay un supermercado y en frente un '
#                           'Bradesco. Además muy completo, No nos faltó '
#                           'nada.\r\n'
#                           'Si volvemos a Río seguro pararemos nuevamente con '
#                           'Ana y José.\r\n',
#               'date': datetime.datetime(2016, 4, 8, 4, 0),
#               'listing_id': '10038496',
#               'reviewer_id': '15238005',
#               'reviewer_name': 'Agustin'},
#              {'_id': '87261130',
#               'comments': 'Local muito agradavel proximo do Mercado Zona Sul - '
#                           'padaria e comercio. Localizado a 1 quadra da praia. '
#                           'Ambiente agradavel host bem prestativa e muito '
#                           'educada. Recomendo a todos que queiram conhecer '
#                           'melhor o Rio!',
#               'date': datetime.datetime(2016, 7, 19, 4, 0),
#               'listing_id': '10038496',
#               'reviewer_id': '83235034',
#               'reviewer_name': 'Raphael'},
#              {'_id': '89793633',
#               'comments': 'Excelente anfitrion siempre estuvo pendiente de lo '
#                           'que necesitabamos. El departamento es muy comodo '
#                           'limpio, y muy bien ubicado.',
#               'date': datetime.datetime(2016, 7, 30, 4, 0),
#               'listing_id': '10038496',
#               'reviewer_id': '12345019',
#               'reviewer_name': 'Luis'},
#              {'_id': '96447291',
#               'comments': 'todo fue como estaba en la descripcion, inclusive '
#                           'tanto en toallas como ropa de cama habia de mas '
#                           'para cambiar, muy satisfecho por todo, ubicasion, '
#                           'internet, tv, comodidades y la atencion de ana, que '
#                           'estuvo siempre dispuesta a atendernos, inclusive '
#                           'dejando un celular para urgencias, colmo nuestras '
#                           'espectatibas',
#               'date': datetime.datetime(2016, 8, 22, 4, 0),
#               'listing_id': '10038496',
#               'reviewer_id': '46538654',
#               'reviewer_name': 'Adrian Adolfo'},
#              {'_id': '98707977',
#               'comments': 'The location is perfect, ideal and safe walking '
#                           'distance to Ipanema and Copacabana, including '
#                           'Arpoador just 800 metres away; cheap for Uber to '
#                           'nearby attractions too. I even walked to Leblon '
#                           'from there in under 40 minutes. \n'
#                           '\n'
#                           'The hosts met me up front and helped me with my '
#                           "luggage. They don't speak English, but are very "
#                           'charming and helpful, so we communicated via '
#                           '(Hidden by Airbnb) Translate, using (Hidden by '
#                           'Airbnb) .\n'
#                           '\n'
#                           'The building is slightly older. One day there was '
#                           'no water in the building due to maintenance. The '
#                           'hosts warned me about this, there was nothing they '
#                           'could do and I was prepared. Only issue is that '
#                           'after the water came back, because of the older '
#                           'pipes, it was brown for a little while, just have '
#                           'to let the taps run for several minutes. \n'
#                           '\n'
#                           "The bed isn't the most comfortable for an extended "
#                           'stay (I was there for eight nights), but for short '
#                           "durations it's fine. \n"
#                           '\n'
#                           'There is a washing machine in the apartment, it '
#                           'works great, I dried my clothes by hanging them on '
#                           'chairs, hooks, etc. \n'
#                           '\n'
#                           'The WiFi is strong and reliable. \n'
#                           '\n'
#                           'There is a grocery store and a couple of reasonably '
#                           'priced restaurants on the block, as well as two '
#                           'different banks. Excellent for visitors. A drug '
#                           'store is also available on the next block at the '
#                           'corner. \n'
#                           '\n'
#                           'Overall the inconveniences were small and the '
#                           'positives of this location was great. ',
#               'date': datetime.datetime(2016, 9, 1, 4, 0),
#               'listing_id': '10038496',
#               'reviewer_id': '20095666',
#               'reviewer_name': 'Asif'},
#              {'_id': '105153541',
#               'comments': 'Ana and Jose were wonderful hosts.  They were there '
#                           'when we arrived and showed us everything.  They '
#                           'provided a cell phone for us to use to be in '
#                           'contact with them and were very patient with our '
#                           'lack of technological experience. They were always '
#                           'helpful and accommodating. The apt. was very '
#                           'comfortable and convenient.  I highly recommend '
#                           'this place.  Ana speaks Portuguese and understands '
#                           'Spanish.  If you speak English, she has friends who '
#                           'can help with the translation.',
#               'date': datetime.datetime(2016, 9, 30, 4, 0),
#               'listing_id': '10038496',
#               'reviewer_id': '81173012',
#               'reviewer_name': 'Maureen'},
#              {'_id': '106849380',
#               'comments': 'A localização e excelente com tudo pertinho. Um '
#                           'supermercado ao lado assim como uma padaria e uma '
#                           'lanchonete.  Tinham muito bons restaurantes nas '
#                           'redondezas, inclusive um 24 horas. ',
#               'date': datetime.datetime(2016, 10, 8, 4, 0),
#               'listing_id': '10038496',
#               'reviewer_id': '24470430',
#               'reviewer_name': 'Gracinha Ferreira'},
#              {'_id': '108096704',
#               'comments': 'A anfitriã Ana Valéria é ótima, simpática, super '
#                           'atenciosa, sempre pronta a ajudar. O ap e os '
#                           'utensílios da casa são super limpos, o banho é '
#                           'ótimo e a cama super confortável. A localização é '
#                           'perfeita. Pretendo voltar! ',
#               'date': datetime.datetime(2016, 10, 14, 4, 0),
#               'listing_id': '10038496',
#               'reviewer_id': '94389738',
#               'reviewer_name': 'Mirian'},
#              {'_id': '108662420',
#               'comments': 'Ana Valéria e seu esposo foram extremamente '
#                           'atenciosos e prestativos. Nos receberam '
#                           'extremamente bem. Nos sentimos em casa. O imóvel é '
#                           'realmente o que aparece nas fotos. Muito bem '
#                           'localizado, limpo e funcional. Excelente.',
#               'date': datetime.datetime(2016, 10, 16, 4, 0),
#               'listing_id': '10038496',
#               'reviewer_id': '80330535',
#               'reviewer_name': 'Cesar'},
#              {'_id': '112297076',
#               'comments': 'Ana is an amazing host, she was very accommodating '
#                           'with check-in time and was very easily reached with '
#                           'any problems, even though none transpired. The '
#                           'apartment is about 1.5 blocks away from the beach '
#                           'with banks, restaurants, and a super market within '
#                           'a 10 minute walk. Would highly recommend staying '
#                           'with Ana to anybody wanting to see Rio.   ',
#               'date': datetime.datetime(2016, 11, 5, 4, 0),
#               'listing_id': '10038496',
#               'reviewer_id': '67404285',
#               'reviewer_name': 'Alex'},
#              {'_id': '114177330',
#               'comments': 'Muito boa estadia. A Valéria foi ótima. Super '
#                           'atenciosa e prestativa. Localização é ótima. Acesso '
#                           'fácil às praia de copa e Ipanema. Muitos '
#                           'restaurantes, mercado....\r\n'
#                           'Local limpo. Eu recomendo. ',
#               'date': datetime.datetime(2016, 11, 16, 5, 0),
#               'listing_id': '10038496',
#               'reviewer_id': '1258230',
#               'reviewer_name': 'Gabriela'},
#              {'_id': '116322190',
#               'comments': 'El departamento es genial, aireado, luminoso y muy '
#                           'bien equipado (aunque necesitarìa una mesa) La zona '
#                           'de Copacabana que habìamos elegido, muy conectado '
#                           'con Ipanema, y a pocas cuadras del metro (Gdor. '
#                           'Osorio) \r\n'
#                           'Anfitriones atentos y dispuestos. Nos encantò !!',
#               'date': datetime.datetime(2016, 11, 29, 5, 0),
#               'listing_id': '10038496',
#               'reviewer_id': '45060159',
#               'reviewer_name': 'Ale'},
#              {'_id': '117194294',
#               'comments': 'A anfitriã e seu marido são muito simpáticos , '
#                           'apartamento ideal para um casal , localização '
#                           'fantástica , gostei muito .',
#               'date': datetime.datetime(2016, 12, 5, 5, 0),
#               'listing_id': '10038496',
#               'reviewer_id': '17216383',
#               'reviewer_name': 'Vinícius'},
#              {'_id': '120439457',
#               'comments': 'Este departamento está a una cuadra de la playa, '
#                           'muy bien ubicado, en plena zona comercial y '
#                           'turística de Copacabana.  Al lado de la puerta de '
#                           'entrada había un supermercado con buenos precios y '
#                           'hay muchas tiendas de diferentes tipos '
#                           'alrededor.\r\n'
#                           'El departamento es tal cual se ve en las fotos, muy '
#                           'acogedor y para nada caluroso. Hay un ventilador de '
#                           'techo en el living para la cama que está allí y un '
#                           'ventilador y aire acondicionado para la cama de dos '
#                           'plazas en la habitación. El departamento estaba muy '
#                           'limpio apenas llegamos, con todo en su lugar. '
#                           'Teníamos todo a nuestra disposición, todo bien '
#                           'ordenado.\r\n'
#                           'Valeria nos recibió en la entrada y nos entregó las '
#                           'llaves en mano, nos explicó todo paso a paso del '
#                           'departamento. Su llavero tenía una tarjeta de '
#                           'descuento para el supermercado, ella nos lo prestó '
#                           'y nos sirvió mucho para hacer las compras. Valeria '
#                           'fue de gran ayuda en todo momento. Previo a llegar '
#                           'se contactó conmigo, también durante la estadía por '
#                           'si necesitábamos algo y previo a nuestra partida. '
#                           'Cuando la contactábamos, teníamos respuesta rápida. '
#                           'Eso nos hizo sentir muy cómodos y nos ayudó.\r\n'
#                           'Tanto el departamento como la anfitriona hicieron '
#                           'que tuvieramos una gran estadía en Copacabana.',
#               'date': datetime.datetime(2016, 12, 10, 5, 0),
#               'listing_id': '10038496',
#               'reviewer_id': '27158989',
#               'reviewer_name': 'Pablo'},
#              {'_id': '121218526',
#               'comments': 'Ana Valéria é uma hospedeira muito legal! O '
#                           'apartamento dela é ótimo com todas as coisas do que '
#                           'você precisa. Super confortável e super bem '
#                           'localizado com um mercado ao lado.\n'
#                           'Não tem como reclamar, tudo é perfeito!!! ',
#               'date': datetime.datetime(2016, 12, 15, 5, 0),
#               'listing_id': '10038496',
#               'reviewer_id': '58233964',
#               'reviewer_name': 'Yoan'},
#              {'_id': '123264653',
#               'comments': 'Era como estaba en el anuncio de airbnb',
#               'date': datetime.datetime(2016, 12, 28, 5, 0),
#               'listing_id': '10038496',
#               'reviewer_id': '47326855',
#               'reviewer_name': 'Sebastian'},
#              {'_id': '129536798',
#               'comments': 'Excelente estadía en el departamento de valeria. La '
#                           'ubicación es inmejorable y es muy cómodo. Ella y su '
#                           'esposo muy atentos y dispuestos a ayudar en todo '
#                           'momento. Sin duda lo recomiendo',
#               'date': datetime.datetime(2017, 1, 31, 5, 0),
#               'listing_id': '10038496',
#               'reviewer_id': '38300289',
#               'reviewer_name': 'Carlos German'},
#              {'_id': '132537926',
#               'comments': 'Muito bom o apartamento! Recomendo e pretendo '
#                           '(Website hidden by Airbnb) acho que seria '
#                           'interessante ter no apto uma cadeira de praia e '
#                           'guarda-sol, quem fica por muitos dias hospedado '
#                           'acaba gastando muito com aluguel na praia.Bem '
#                           'localizado, limpo e apto bem dividido.Valeria foi '
#                           'super atenciosa e receptiva, sempre tentando ajudar '
#                           'no que fosse possível.',
#               'date': datetime.datetime(2017, 2, 18, 5, 0),
#               'listing_id': '10038496',
#               'reviewer_id': '97369017',
#               'reviewer_name': 'Hingra'},
#              {'_id': '137610557',
#               'comments': 'Fue realmente un placer alojarnos en el '
#                           'departamento de Copacabana. Perfectamente ubicado, '
#                           'todo funciona impecable, abajo hay un supermercado '
#                           'completo, restaurantes y las playas bien próximas. '
#                           'Y Ana Valeria, la anfitriona, un encanto, siempre '
#                           'conectada para saber sobre nuestras necesidades. '
#                           'Fue un viaje espectacular. EStamos muy agradecidos. '
#                           'Vamos a volver.',
#               'date': datetime.datetime(2017, 3, 16, 4, 0),
#               'listing_id': '10038496',
#               'reviewer_id': '44956140',
#               'reviewer_name': 'Carina'},
#              {'_id': '139244084',
#               'comments': 'Hermoso depto. Cerca de la playa de ipanema . Ana '
#                           'Valeria se preocupo para que nuestra estadia sea '
#                           'buena.Excelente ubicacion, comodo y limpio',
#               'date': datetime.datetime(2017, 3, 24, 4, 0),
#               'listing_id': '10038496',
#               'reviewer_id': '106171754',
#               'reviewer_name': 'Hernan'},
#              {'_id': '140362809',
#               'comments': 'Todo perfecto. El departamento es muy lindo, '
#                           'completo, limpio y todo funciona perfectamente. '
#                           'Tanto Ana Valeria como José siempre atentos y en '
#                           'comunicación. Super recomendable!',
#               'date': datetime.datetime(2017, 3, 29, 4, 0),
#               'listing_id': '10038496',
#               'reviewer_id': '94973779',
#               'reviewer_name': 'Priscila'},
#              {'_id': '141723867',
#               'comments': 'Excelente ubicación y departamento muy hermoso. '
#                           'Valeria fue muy amable y comunicativa. Estuvo en '
#                           'cada detalle y ademas nos facilitó un lugar para '
#                           'poder dejar nuestras valijas luego del check out, '
#                           'ya que viajábamos tarde. Muy recomendable! '
#                           'Seguramente volveremos pronto.',
#               'date': datetime.datetime(2017, 4, 4, 4, 0),
#               'listing_id': '10038496',
#               'reviewer_id': '114863139',
#               'reviewer_name': 'Natalia'},
#              {'_id': '142801153',
#               'comments': 'Um bom apartamento, pertinho da pedra do Arpoardor '
#                           'e a 1 quadra da praia de Copacabana. Ônibus fácil '
#                           'para todo o canto, supermercado embaixo do prédio. '
#                           'Apartamento exatamente igual ao descrito no '
#                           'anúncio.',
#               'date': datetime.datetime(2017, 4, 9, 4, 0),
#               'listing_id': '10038496',
#               'reviewer_id': '12398467',
#               'reviewer_name': 'Louise'},
#              {'_id': '144728300',
#               'comments': 'Apartamento bem equipado, localização excelente '
#                           '(tem tudo perto) e anfitriã muito disponível para '
#                           'as informações necessárias. Recomendo demais!',
#               'date': datetime.datetime(2017, 4, 16, 4, 0),
#               'listing_id': '10038496',
#               'reviewer_id': '22762689',
#               'reviewer_name': 'Achilles'},
#              {'_id': '148736479',
#               'comments': 'Super appartement, idéalement situé à deux pas de '
#                           "Copacabana, 10 minutes d'Ipanéma et du métro. "
#                           "L'appartement est fonctionnel, propre, agréable, "
#                           "sécurisé. En bas de l'immeuble, il y a un petit "
#                           'centre commercial bien pratique et une délicieuse '
#                           'boulangerie. Nous sommes restés 15 jours et avons '
#                           'énormément visité. Les plages à proximité sont '
#                           'vivantes. Enfin, merci à Anna Valéria pour nos '
#                           'échanges et ses attentions. Son ami Fernando nous a '
#                           "fait le transfert de l'appartement à l'aéroport. Il "
#                           'est adorable. Beaucoup de choses à découvrir à Rio. '
#                           'Nous avons fait un très beau voyage.',
#               'date': datetime.datetime(2017, 5, 1, 4, 0),
#               'listing_id': '10038496',
#               'reviewer_id': '14703886',
#               'reviewer_name': 'Christophe'},
#              {'_id': '156164871',
#               'comments': 'Super Recomendo! O apto é impecável, funcional, '
#                           'aconchegante e o melhor numa localização '
#                           'privilegiada! Sem contar o atendimento PRIME da Ana '
#                           'Valéria! Excelente!',
#               'date': datetime.datetime(2017, 5, 29, 4, 0),
#               'listing_id': '10038496',
#               'reviewer_id': '121580398',
#               'reviewer_name': 'Ricardo'},
#              {'_id': '158815208',
#               'comments': 'Ana, fue un maravilloso viaje, sin la comodidad y '
#                           'buena ubicación del departamento no hubiese sido '
#                           'igual.  \n'
#                           'Muito obrigado!',
#               'date': datetime.datetime(2017, 6, 8, 4, 0),
#               'listing_id': '10038496',
#               'reviewer_id': '119276115',
#               'reviewer_name': 'Sergio'},
#              {'_id': '167658254',
#               'comments': 'If you want something close to the beach and to '
#                           'live like a carioca this is the spot. Close to '
#                           'metro, ipanema, copa, supermarket, paderia, tudo! '
#                           'Great communication. Thank you for the perfect '
#                           'place Ana! ',
#               'date': datetime.datetime(2017, 7, 7, 4, 0),
#               'listing_id': '10038496',
#               'reviewer_id': '16069925',
#               'reviewer_name': 'Leah'},
#              {'_id': '172657826',
#               'comments': 'La verdad es que fue todo muy lindo!!! Ana Valeria '
#                           'tiene mucha buena onda, se preocupo porque siempre '
#                           'este todo bien, el departamento es muy amplio, '
#                           'cómodo, tiene todo lo que se precisa, muy limpio y '
#                           'ordenado, todo funciona a la perfección. La '
#                           'ubicación es espectacular, cerca de la playa y a '
#                           'minutos de Ipanema. Ana Valeria una genia, una '
#                           'persona muy cálida. Muy recomendable!!!!!',
#               'date': datetime.datetime(2017, 7, 21, 4, 0),
#               'listing_id': '10038496',
#               'reviewer_id': '131973196',
#               'reviewer_name': 'Bel'},
#              {'_id': '175339972',
#               'comments': 'Muy bien ubicado, Valeria fue muy amable y '
#                           'atenta. \n'
#                           'Sin duda recomindo su departamento.',
#               'date': datetime.datetime(2017, 7, 28, 4, 0),
#               'listing_id': '10038496',
#               'reviewer_id': '40998565',
#               'reviewer_name': 'Talia'},
#              {'_id': '193197117',
#               'comments': 'Excelente localização e a Valeria uma excelente '
#                           'anfitriã, super preocupada em nos deixar muito a '
#                           'vontade. O apartamento tem uma energia muito boa.',
#               'date': datetime.datetime(2017, 9, 12, 4, 0),
#               'listing_id': '10038496',
#               'reviewer_id': '110978677',
#               'reviewer_name': 'Fernanda'},
#              {'_id': '197318690',
#               'comments': 'Ideal para um casal, com ótima localização próximo '
#                           'a supermercado, restaurantes e bancos. Valéria é '
#                           'super receptiva e nos recebeu muito bem. Ficaria '
#                           'hospedada aqui novamente. :)',
#               'date': datetime.datetime(2017, 9, 25, 4, 0),
#               'listing_id': '10038496',
#               'reviewer_id': '40645058',
#               'reviewer_name': 'Mariana'},
#              {'_id': '206271447',
#               'comments': 'La zona es la mejor, cerca de pla 2 mejores playas '
#                           'de Rio, el departamento es bastante comodo y es tal '
#                           'como lo muestran en fotos, Ana Valeria y su esposo '
#                           'son extremadamente amables y serviciales, nos '
#                           'ayudaron mucho. Un pequeño punto a mejorar son los '
#                           'canales de Tv que solo son unos 6 y  solo un par de '
#                           'entretenimiento.',
#               'date': datetime.datetime(2017, 10, 24, 4, 0),
#               'listing_id': '10038496',
#               'reviewer_id': '70411464',
#               'reviewer_name': 'Edson Gary'},
#              {'_id': '209485024',
#               'comments': 'Ana Valéria é muito prestativa e as fotos do '
#                           'apartamento refletem realmente como é. Localização '
#                           'excelente. \n'
#                           'Recomendo',
#               'date': datetime.datetime(2017, 11, 5, 4, 0),
#               'listing_id': '10038496',
#               'reviewer_id': '42865577',
#               'reviewer_name': 'Adalton'},
#              {'_id': '216576249',
#               'comments': "Great location lot of amenities we're close and is "
#                           'easy to work with I would stay there again',
#               'date': datetime.datetime(2017, 12, 4, 5, 0),
#               'listing_id': '10038496',
#               'reviewer_id': '149141767',
#               'reviewer_name': 'Danny'},
#              {'_id': '218212792',
#               'comments': 'Ótima localização, tudo a mão, excelente '
#                           'atendimento, preço justo, lugar amplo e '
#                           'aconchegante. Recomendo.',
#               'date': datetime.datetime(2017, 12, 11, 5, 0),
#               'listing_id': '10038496',
#               'reviewer_id': '155795023',
#               'reviewer_name': 'Luís Fernando'},
#              {'_id': '220059333',
#               'comments': 'Nice location. Great host . I do recoment.',
#               'date': datetime.datetime(2017, 12, 20, 5, 0),
#               'listing_id': '10038496',
#               'reviewer_id': '22443804',
#               'reviewer_name': 'Douglas'},
#              {'_id': '223023774',
#               'comments': 'Nice place and location!\nThanks!',
#               'date': datetime.datetime(2017, 12, 31, 5, 0),
#               'listing_id': '10038496',
#               'reviewer_id': '77730304',
#               'reviewer_name': 'Facundo'},
#              {'_id': '225106904',
#               'comments': 'O apto é super bem localizado, funcional e limpo. O '
#                           'prédio é antigo (como todos no bairro de '
#                           'Copacabana) mas o apto em si é muito bom. Apesar de '
#                           'estar em avenida super movimentada, o barulho '
#                           'externo foi menor do que eu esperava. Dormi muito '
#                           'bem. Eu e minha familia gostamos muito da nossa '
#                           'estadia nele. Tem Mercado, bancos, padaria na mesma '
#                           'quadra e fica 1 quadra da praia de Copacabana.',
#               'date': datetime.datetime(2018, 1, 5, 5, 0),
#               'listing_id': '10038496',
#               'reviewer_id': '133210672',
#               'reviewer_name': 'Natasha'},
#              {'_id': '226386493',
#               'comments': 'Fue una estadía increíble! Ana Valeria fue muy '
#                           'atenta y el departamento impecable, súper bien '
#                           'equipado y excelente ubicación. Mejor que en las '
#                           'fotos!  Estábamos a pocos pasos de las playas de '
#                           'Copacabana e Ipanema. El entorno súper seguro, con '
#                           'perfecto acceso a compras y restorantes. Quedamos '
#                           'felices con nuestra visita a Río, totalmente '
#                           'recomendado',
#               'date': datetime.datetime(2018, 1, 10, 5, 0),
#               'listing_id': '10038496',
#               'reviewer_id': '45908423',
#               'reviewer_name': 'Florencia'},
#              {'_id': '230187055',
#               'comments': 'Hermoso departamento.. el aire acondicionado y '
#                           'ventiladores excelentes. Departamento muy limpio, '
#                           'contaba con todo lo necesario: juguera, tostadora, '
#                           'lavadora, zona para tender ropa, plancha... todo. '
#                           'El sector... el mejor.. a una cuadra de la playa, '
#                           'al lado un mercado para comprar frutas..  muy cerca '
#                           'del supermercado... farmacias, banco, la playa '
#                           'hermosa... muy tranquilo, no tuve ningún problema, '
#                           'muchos turistas.. todo muy iluminado. A dos cuadras '
#                           'está el hotel Atlantis... donde compré 3 tours a : '
#                           'Angra do Reis/Isla Grande, Búzios y uno a Cabo do '
#                           'Reis... todos excelentes 200 reales por persona. '
#                           'Recomiendo un restaurante a 2 cuadras del depto de '
#                           'Valeria se llama Eclipse... ricas pizas a 12,5 '
#                           'reales... hamburguesas con papa a 18 reales... '
#                           'carnes con agregados(picaña) a 33 reales... muy '
#                           'rico y buen precio. Valeria una excelente '
#                           'anfitriona, muy confiable. Uber funciona sin '
#                           'problema. Lo pasamos increíble.',
#               'date': datetime.datetime(2018, 1, 27, 5, 0),
#               'listing_id': '10038496',
#               'reviewer_id': '106652946',
#               'reviewer_name': 'Milena'},
#              {'_id': '237316959',
#               'comments': 'El dpto es como en las fotos, Ana Valeria super '
#                           'amable, nos ayudo con sugerencias turisticas . Esta '
#                           'bien super bien ubicado, entre copacabana e '
#                           'ipanema.',
#               'date': datetime.datetime(2018, 2, 22, 5, 0),
#               'listing_id': '10038496',
#               'reviewer_id': '81957168',
#               'reviewer_name': 'Valeria'},
#              {'_id': '239373208',
#               'comments': 'L appartement est très bien situé, à 2 pas de la '
#                           'plage de Copacabana et tout près d Ipanema, dans un '
#                           'quartier sans problème \n'
#                           'Il y a juste en bas un petit supermarché très  bien '
#                           'approvisionné pour cuisiner\n'
#                           'Nos hôtes nous ont très bien accueilli et ont été '
#                           'très disponibles pour communiquer pendant tout le '
#                           'séjour !',
#               'date': datetime.datetime(2018, 3, 1, 5, 0),
#               'listing_id': '10038496',
#               'reviewer_id': '67840133',
#               'reviewer_name': 'Cecile'},
#              {'_id': '242202709',
#               'comments': 'A Ana Valéria é com ctz uma superanfitriã, nos '
#                           'recebeu presencialmente antes do horário de checkin '
#                           'em virtude da acomodação das bagagens e o fez com '
#                           'muita simpatia e alegria. Foi solicita em tudo q '
#                           'foi perguntado, sempre de forma rápida e prática. '
#                           'Na hora do checkout tbm foi flexível em nos '
#                           'auxiliar para acomodação da bagagem à espera do '
#                           'horário do vôo. O ap é muito limpo e aconchegante, '
#                           'com vários utensílios domésticos q facilitam a vida '
#                           'do turista para q economize em sua estadia. A '
#                           'localização é privilegiada, a uma quadra da praia '
#                           'de Copacabana e a 5 min caminhando da praia do '
#                           'Arpoador, nossa preferida, que aliás, é bom '
#                           'ressaltar, estava muito bem policiada durante minha '
#                           'estadia de 7 dias no Rio. Superecomendo o ap de Ana '
#                           'Valéria e com ctz voltarei em breve.',
#               'date': datetime.datetime(2018, 3, 11, 5, 0),
#               'listing_id': '10038496',
#               'reviewer_id': '94207939',
#               'reviewer_name': 'Júnior'},
#              {'_id': '243563030',
#               'comments': 'Local super bem localizado, amplo, perto de todas '
#                           'as comodidades possíveis...praia fica bem '
#                           'próximo...',
#               'date': datetime.datetime(2018, 3, 16, 4, 0),
#               'listing_id': '10038496',
#               'reviewer_id': '105008685',
#               'reviewer_name': 'Ernani'},
#              {'_id': '246019537',
#               'comments': 'O apartamento é bem localizado,  limpo e a Ana '
#                           'Valéria é muito atenciosa. \n'
#                           'Voltaria com certeza. ',
#               'date': datetime.datetime(2018, 3, 24, 4, 0),
#               'listing_id': '10038496',
#               'reviewer_id': '56758262',
#               'reviewer_name': 'Fatima'},
#              {'_id': '250030545',
#               'comments': 'Me hospedei com mais dois amigos no apto da Ana! '
#                           'Foi tudo perfeito! Ela nos ajudou com tudo que '
#                           'precisávamos!\n'
#                           'O apto está em boas condições, tinha tudo que '
#                           'precisávamos, desde utensílios de cozinha até '
#                           'roupas de cama e banho.\n'
#                           'A localização é ótima! Uma quadra do posto 6 em '
#                           'Copacabana e 10min de Ipanema! Possui supermercado, '
#                           'padaria e farmácias na porta do edifício! \n'
#                           'Tivemos uma ótima estada! Obrigado Ana!',
#               'date': datetime.datetime(2018, 4, 3, 4, 0),
#               'listing_id': '10038496',
#               'reviewer_id': '49892754',
#               'reviewer_name': 'Victor'},
#              {'_id': '252180209',
#               'comments': 'Espaço muito bem localizado, região tranquila e '
#                           '(Website hidden by Airbnb) certeza voltarei a me '
#                           'hospedar lá! Os proprietários são de fácil '
#                           'comunicação e são prestativos.',
#               'date': datetime.datetime(2018, 4, 9, 4, 0),
#               'listing_id': '10038496',
#               'reviewer_id': '165668545',
#               'reviewer_name': 'João Paulo Anselmo'},
#              {'_id': '255781870',
#               'comments': 'Nos encanto Río! \n'
#                           'AnaValeria súper amable y encantadora.\n'
#                           'El departamento muy cómodo y muy lindo, tal cual '
#                           'las fotos.\n'
#                           'Todo perfecto!\n'
#                           'Esperamos volver!\n'
#                           'Gracias!!!',
#               'date': datetime.datetime(2018, 4, 21, 4, 0),
#               'listing_id': '10038496',
#               'reviewer_id': '170949772',
#               'reviewer_name': 'Guido Jorge'},
#              {'_id': '261993239',
#               'comments': 'Ana Valeria a été super réactive dès notre '
#                           'réservation. Elle était là pour nous accueillir et '
#                           'nous montrer l appartement. Celui-ci était bien '
#                           'équipé notamment la cuisine, top comme ça nous '
#                           'avons pu preparer les petits plats pour bébé. L '
#                           'emplacement est idéal pour qui souhaite profiter d '
#                           'Ipanema e Copacabana. Restaurant et bars à '
#                           'proximité. Nous avons passé 4 jours à Rio très '
#                           'sympa.',
#               'date': datetime.datetime(2018, 5, 7, 4, 0),
#               'listing_id': '10038496',
#               'reviewer_id': '12426799',
#               'reviewer_name': 'Estelle & Jean'},
#              {'_id': '264999793',
#               'comments': 'Excelente departamento y muy bien ubicado entre las '
#                           'playas de Copacabana (1 cuadra) e Ipanema (5 '
#                           'cuadras). Tiene todas las comodidades para tener '
#                           'una excelente estancia en una ciudad como Río de '
#                           'Janeiro! Hay un supermercado justo al lado del '
#                           'edificio, muy cómodo para abastecerse a toda hora, '
#                           'y bancos enfrente en la misma cuadra. Ya me he '
#                           'alojado 2 veces aquí y volvería a hacerlo! La '
#                           'hospitalidad de Valeria fue excelente ambas veces, '
#                           'tanto al ingresar como al salir del departamento.',
#               'date': datetime.datetime(2018, 5, 15, 4, 0),
#               'listing_id': '10038496',
#               'reviewer_id': '56705324',
#               'reviewer_name': 'Daniel'},
#              {'_id': '291815191',
#               'comments': 'm legal',
#               'date': datetime.datetime(2018, 7, 16, 4, 0),
#               'listing_id': '10038496',
#               'reviewer_id': '39723696',
#               'reviewer_name': 'David'},
#              {'_id': '297817291',
#               'comments': 'Ana was a fantastic host. The apartment was very '
#                           'clean and comfortable. The location was perfect.  '
#                           'We had a great trip to Rio. I highly recommend.',
#               'date': datetime.datetime(2018, 7, 28, 4, 0),
#               'listing_id': '10038496',
#               'reviewer_id': '5881328',
#               'reviewer_name': 'Sed And Luciana'},
#              {'_id': '303959226',
#               'comments': 'Excelente alojamiento con ubicación ideal para '
#                           'conocer río, supermercado a 10 metros, equipado con '
#                           'todo lo necesario y muy buena atención de parte de '
#                           'Ana Valeria. Muy recomendable\n',
#               'date': datetime.datetime(2018, 8, 8, 4, 0),
#               'listing_id': '10038496',
#               'reviewer_id': '204292479',
#               'reviewer_name': 'Miguel'},
#              {'_id': '307011277',
#               'comments': 'Excelente apartamento super limpo, arejado e '
#                           'espaçoso. A anfitriã dispensa comentários, '
#                           'excelente pessoa, sempre disposta a ajudar, super '
#                           'prestativa e um amor de (Website hidden by Airbnb) '
#                           'certeza iremos retornar é super recomendo',
#               'date': datetime.datetime(2018, 8, 13, 4, 0),
#               'listing_id': '10038496',
#               'reviewer_id': '104924380',
#               'reviewer_name': 'Guaracy'},
#              {'_id': '315749969',
#               'comments': 'A minha estadia no apartamento da Ana Valéria foi '
#                           'incrível! O apartamento é exatamente como mostram '
#                           'as fotos, é muito confortável e acomoda '
#                           'tranquilamente até quatro pessoas! Tem tudo o que é '
#                           'preciso para uma boa estadia, como utensílios de '
#                           'cozinha e roupas de cama e banho! Os banheiros '
#                           'estavam extremamente limpos, a recepção e a '
#                           'comunicação foi ótima! Além disso, é preciso '
#                           'destacar a localização, bem próxima às praias de '
#                           'Copacabana e Ipanema, e de estar no mesmo '
#                           'quarteirão de lanchonete, padaria, restaurante, '
#                           'supermercado, farmácia e bancos! Super indico e com '
#                           'certeza voltaria a me hospedar lá.',
#               'date': datetime.datetime(2018, 8, 29, 4, 0),
#               'listing_id': '10038496',
#               'reviewer_id': '204842220',
#               'reviewer_name': 'José Vângelo'},
#              {'_id': '335976265',
#               'comments': 'Wir haben zu dritt 3 Nächte im Apartment von Ana '
#                           'Valeria verbracht. Die Kommunikation hat sehr gut '
#                           'funktioniert und wir konnten das Apartment rasch '
#                           'finden. Wir wurden sehr herzlich begrüsst! Der '
#                           'Standort ist perfekt, da der Strand von Copacabana '
#                           '(ca.3 Min.) so wie die Ipanema (ca.10Min) zu Fuss '
#                           'zu erreiche sind. Zudem ist ein Supermarkt direkt '
#                           'neben dem Eingang! Wir haben uns auch Nachts sicher '
#                           'gefühlt und würden die Unterkunft herzlichst weiter '
#                           'empfehlen.',
#               'date': datetime.datetime(2018, 10, 13, 4, 0),
#               'listing_id': '10038496',
#               'reviewer_id': '23072673',
#               'reviewer_name': 'Laura'},
#              {'_id': '338815440',
#               'comments': 'Appartement propre , confortable et parfaitement '
#                           'situé. Valeria est très réactive, j’ai eu un soucis '
#                           'avec le pommeau de douche qui a cassé le soir et le '
#                           'lendemain matin c’était changé. Je recommande sans '
#                           'aucun doute.',
#               'date': datetime.datetime(2018, 10, 20, 4, 0),
#               'listing_id': '10038496',
#               'reviewer_id': '205528285',
#               'reviewer_name': 'Fabien'},
#              {'_id': '341679758',
#               'comments': 'Maravilhosa estadia! Ap muito aconchegante, bem '
#                           'localizado, perto da praia, comércios, restaurantes '
#                           'e metrô. Ana Valéria é um amor!',
#               'date': datetime.datetime(2018, 10, 27, 4, 0),
#               'listing_id': '10038496',
#               'reviewer_id': '173489896',
#               'reviewer_name': 'Amoriara'},
#              {'_id': '346986452',
#               'comments': 'Regular...',
#               'date': datetime.datetime(2018, 11, 10, 5, 0),
#               'listing_id': '10038496',
#               'reviewer_id': '222299471',
#               'reviewer_name': 'Juan'},
#              {'_id': '354036835',
#               'comments': 'O apartamento fica a menos de 2 quadras da praia e '
#                           'do Forte de Copacabana (que é um lugar que vale a '
#                           'pena visitar). Um pouquinho depois, caminhando, já '
#                           'se chega no Arpoador. Na mesma quadra do apto tem '
#                           'supermercado, padaria e outros comércios. Ana '
#                           'Valéria foi sempre simpática e nos entregou o apto '
#                           'limpo e com todos os itens que poderíamos precisar, '
#                           'inclusive duas cadeiras de praia. Excelente! '
#                           'Recomendamos!',
#               'date': datetime.datetime(2018, 11, 30, 5, 0),
#               'listing_id': '10038496',
#               'reviewer_id': '167966847',
#               'reviewer_name': 'Cristiane'},
#              {'_id': '357036814',
#               'comments': 'Com certeza recomendo o local, excelente recepçao e '
#                           'disponibilidade. Valeria sempre foi atenciosa e '
#                           'preocupada c nosso bem estar. Espaço amplo e muito '
#                           'bem localizado. Espero voltar mais vezes.',
#               'date': datetime.datetime(2018, 12, 9, 5, 0),
#               'listing_id': '10038496',
#               'reviewer_id': '153445227',
#               'reviewer_name': 'Marcia'},
#              {'_id': '368187046',
#               'comments': 'This is the second time I’ve stayed with Ana '
#                           'Valeria. Both stays were about a month. Ana Valeria '
#                           'is a sweet and considerate host. \n'
#                           '\n'
#                           'I would not call the apartment luxurious, but it '
#                           'has everything you need and it’s clean. A small '
#                           'kitchen, and laundry is a must for me. If you’re '
#                           'like me, and you love Rio, and go to the beach '
#                           'everyday, there is no better location. I can hop on '
#                           'a skateboard and get to Leme or leblon, no prob. \n'
#                           '\n'
#                           'I won’t say more, so when I want to book again it '
#                           'will be available!!\n'
#                           '\n'
#                           'Thank you Ana Valeria. Beijão, amiga.',
#               'date': datetime.datetime(2019, 1, 6, 5, 0),
#               'listing_id': '10038496',
#               'reviewer_id': '16069925',
#               'reviewer_name': 'Leah'},
#              {'_id': '402138734',
#               'comments': 'Incrível hospitalidade, fizemos o check-in antes do '
#                           'horário combinado! O apartamento é super legal, '
#                           'extremamente bem localizado. Panificadoras, '
#                           'mercados, restaurantes, bancos, metro, praias e '
#                           'diversas coisas ao alcance. Ar condicionado antigo '
#                           'mas funciona bem e é limpo.',
#               'date': datetime.datetime(2019, 1, 17, 5, 0),
#               'listing_id': '10038496',
#               'reviewer_id': '189203898',
#               'reviewer_name': 'Murylo'},
#              {'_id': '403178477',
#               'comments': 'Tudo conforme anunciado. Recomendo e voltaria.',
#               'date': datetime.datetime(2019, 1, 20, 5, 0),
#               'listing_id': '10038496',
#               'reviewer_id': '21231279',
#               'reviewer_name': 'Pedro'},
#              {'_id': '404802128',
#               'comments': 'O apartamento da Ana Valéria é ótimo em todas as '
#                           'questões... a localização é fantástica. A Ana '
#                           'Valéria é uma excelente anfitriã, nos recebeu muito '
#                           'bem com alguns mimos extras. Adorei meus dias no '
#                           'apartamento dela!',
#               'date': datetime.datetime(2019, 1, 25, 5, 0),
#               'listing_id': '10038496',
#               'reviewer_id': '193776680',
#               'reviewer_name': 'Claudineia'},
#              {'_id': '406107824',
#               'comments': 'Tudo perfeito! O apto é muito bem localizado e '
#                           'atendeu perfeitamente minha família. Anfitriã '
#                           'prestativa e atenciosa.',
#               'date': datetime.datetime(2019, 1, 28, 5, 0),
#               'listing_id': '10038496',
#               'reviewer_id': '144134435',
#               'reviewer_name': 'Alessandra'}],
#  'room_type': 'Entire home/apt',
#  'security_deposit': Decimal128('600.00'),
#  'space': 'The apartment has a living room, wash room, suite and an American '
#           "kitchen. The bedroom has a double bed and there's a bunk bed in the "
#           'living room. It is very well located, in the Copacabana beach block '
#           'and just a few blocks from Arpoador and Ipanema. You can walk to '
#           'any of those beaches. It has internet wifi, tv, air conditioning in '
#           'the bedroom, ceiling fans in the living room and the bedroom and an '
#           'equipped kitchen with cooker, fridge, washing machine, microwave '
#           'and utensils. Ease of public transportation, banks, markets and '
#           'restaurants.',
#  'summary': 'The Apartment has a living room, toilet, bedroom (suite) and '
#             'American kitchen. Well located, on the Copacabana beach block a '
#             '05 Min. walk from Ipanema beach (Arpoador). Internet wifi, cable '
#             'tv, air conditioning in the bedroom, ceiling fans in the bedroom '
#             'and living room, kitchen with microwave, cooker, Blender, dishes, '
#             'cutlery and service area with fridge, washing machine, '
#             'clothesline for drying clothes and closet with several utensils '
#             'for use.  The property boasts 45 m2.',
#  'transit': 'On the street there is plenty of transport and the subway station '
#             'is nearby (06 blocks). To get to the Christ the Redeemer Statue '
#             'there are the options of Metro, bus (at the door) or taxi and the '
#             'Sugar Loaf (pão de açúcar), bus (at the door), cab, all very '
#             'close.'}

# %%
#method2 - size project하기. 

for i in db.airbnb.aggregate([{"$match":{"reviews":{"$exists":True}}},
                             {"$project":{
                                 "_id":1,
                                 "hostname":"$host.host_name",
                                 "number_of_reviews":{"$size":"$reviews"}}},
                             {"$limit":10}
                             ]):
    pprint(i)
# Out:
# {'_id': '10021707', 'hostname': 'Josh', 'number_of_reviews': 1}
# {'_id': '10009999', 'hostname': 'Ynaie', 'number_of_reviews': 0}
# {'_id': '10030955', 'hostname': 'Livia', 'number_of_reviews': 0}
# {'_id': '10047964', 'hostname': 'Zeynep', 'number_of_reviews': 1}
# {'_id': '10057447', 'hostname': 'Konstantin', 'number_of_reviews': 0}
# {'_id': '10051164', 'hostname': 'Beatriz', 'number_of_reviews': 1}
# {'_id': '10057826', 'hostname': 'Mae', 'number_of_reviews': 5}
# {'_id': '10059244', 'hostname': 'Caro', 'number_of_reviews': 0}
# {'_id': '10059872', 'hostname': 'Giovanni', 'number_of_reviews': 3}
# {'_id': '10066928', 'hostname': 'Margaux', 'number_of_reviews': 0}

# %%
for i in db.airbnb.aggregate([{"$project":{"num_review":{"$filter":{
                            "input":"$reviews",
                            "as":"review",
                            "cond":{"$lte":[{"$size":"$reviews"},3]}}}}},
                             {"$match":{"num_review":{"$ne":[]}}},
                             {"$limit":1}
                             ]):
    pprint(i)
# Out:
# {'_id': '10021707',
#  'num_review': [{'_id': '61050713',
#                  'comments': 'Josh was out of town during my 1 month stay. His '
#                              'roommates greeted and helped get me settled. '
#                              'They were great hosts and all around cool '
#                              "people. I'm a Brooklynite, but have never lived "
#                              'in Bushwick.\r\n'
#                              "If you're looking for an hip, authentic, and "
#                              'convenient Brooklyn experience, this spot is for '
#                              'you.  You can literally see the Subway platform '
#                              "from Josh's window. Also a couple steps away "
#                              'from anything you could possibly need... '
#                              'restaurants, juice bar, organic grocery, etc. ',
#                  'date': datetime.datetime(2016, 1, 31, 5, 0),
#                  'listing_id': '10021707',
#                  'reviewer_id': '52006105',
#                  'reviewer_name': 'Antoine'}]}

# %%
for i in db.funds.aggregate([{"$project":{"rounds_over_8000000":{"$filter":
                                                                 {"input":"$funding_rounds",
                                                                 "as":"round",
                                                                 "cond":{"$gte":["$$round.raised_amount",8000000]}}}}},
                            {"$match":{"rounds_over_8000000":{"$ne":[]}}}]):

    pprint(i)
# Out:
# {'_id': ObjectId('61167af198608fe75d51477e'),
#  'rounds_over_8000000': [{'raised_amount': 9297130, 'round_code': 'd'}]}
# {'_id': ObjectId('61167af198608fe75d51477f'),
#  'rounds_over_8000000': [{'raised_amount': 9737827, 'round_code': 'b'},
#                          {'raised_amount': 9606464, 'round_code': 'c'}]}
# {'_id': ObjectId('61167af198608fe75d514780'),
#  'rounds_over_8000000': [{'raised_amount': 9193583, 'round_code': 'a'}]}
# {'_id': ObjectId('61167af198608fe75d514782'),
#  'rounds_over_8000000': [{'raised_amount': 8544121, 'round_code': 'a'}]}
# {'_id': ObjectId('61167af198608fe75d514783'),
#  'rounds_over_8000000': [{'raised_amount': 9988785, 'round_code': 'a'},
#                          {'raised_amount': 8918466, 'round_code': 'd'},
#                          {'raised_amount': 8302021, 'round_code': 'e'}]}

# %% [markdown]
# #### \\$slice ,\$arrayElemAt

# %%
#airbnb amenities가 제공된다면,
#그 첫번째 요소를 가져와보자.
#$arrayElemAt

for i in db.airbnb.aggregate([{"$match":{"amenities":{"$exists":True}}},
                             {"$project":{"First_amenity_provided":{"$arrayElemAt":["$amenities",0]}}},
                             {"$limit":2}]):
    pprint(i)
# Out:
# {'First_amenity_provided': 'Internet', '_id': '10021707'}
# {'First_amenity_provided': 'Wifi', '_id': '10009999'}

# %%
#airbnb amenities가 제공되고, 그게 5개 이상이면 제공되는 amenities의 두번째부터 3개를 가져와보자.
#$slice

for i in db.airbnb.aggregate([{"$match":{"$expr":{"$gte":[{"$size":"$amenities"},5]}}},
                             {"$project":{"second_to_firth_amenity":{"$slice":["$amenities",1,3]}}},
                             {"$limit":2}]):
    pprint(i)
# Out:
# {'_id': '10021707',
#  'second_to_firth_amenity': ['Wifi', 'Air conditioning', 'Kitchen']}
# {'_id': '10009999',
#  'second_to_firth_amenity': ['Wheelchair accessible',
#                              'Kitchen',
#                              'Free parking on premises']}

# %% [markdown]
# #### accumulator

# %%
#fund에서 최고값만 가져와보자.
for i in db.funds.aggregate([{"$project":{"Largest_fund":{"$max":"$funding_rounds.raised_amount"}}}]):
    pprint(i)
# Out:
# {'Largest_fund': 9297130, '_id': ObjectId('61167af198608fe75d51477e')}
# {'Largest_fund': 9737827, '_id': ObjectId('61167af198608fe75d51477f')}
# {'Largest_fund': 9193583, '_id': ObjectId('61167af198608fe75d514780')}
# {'Largest_fund': 7506110, '_id': ObjectId('61167af198608fe75d514781')}
# {'Largest_fund': 8544121, '_id': ObjectId('61167af198608fe75d514782')}
# {'Largest_fund': 9988785, '_id': ObjectId('61167af198608fe75d514783')}
# {'Largest_fund': 7343947, '_id': ObjectId('61167af198608fe75d514784')}

# %%
#fund에서 펀딩 평균을 가져와보자.
for i in db.funds.aggregate([{"$project":{"Largest_fund":{"$avg":"$funding_rounds.raised_amount"}}}]):
    pprint(i)
# Out:
# {'Largest_fund': 7216487.833333333, '_id': ObjectId('61167af198608fe75d51477e')}
# {'Largest_fund': 4185567.8333333335,
#  '_id': ObjectId('61167af198608fe75d51477f')}
# {'Largest_fund': 5183653.5, '_id': ObjectId('61167af198608fe75d514780')}
# {'Largest_fund': 5220760.333333333, '_id': ObjectId('61167af198608fe75d514781')}
# {'Largest_fund': 3637726.6666666665,
#  '_id': ObjectId('61167af198608fe75d514782')}
# {'Largest_fund': 6504653.0, '_id': ObjectId('61167af198608fe75d514783')}
# {'Largest_fund': 4791044.333333333, '_id': ObjectId('61167af198608fe75d514784')}

# %%
#fund에서 최저값만 가져와보자.
for i in db.funds.aggregate([{"$project":{"Largest_fund":{"$min":"$funding_rounds.raised_amount"}}}]):
    pprint(i)
# Out:
# {'Largest_fund': 3479603, '_id': ObjectId('61167af198608fe75d51477e')}
# {'Largest_fund': 509318, '_id': ObjectId('61167af198608fe75d51477f')}
# {'Largest_fund': 2567725, '_id': ObjectId('61167af198608fe75d514780')}
# {'Largest_fund': 2981034, '_id': ObjectId('61167af198608fe75d514781')}
# {'Largest_fund': 573930, '_id': ObjectId('61167af198608fe75d514782')}
# {'Largest_fund': 1878589, '_id': ObjectId('61167af198608fe75d514783')}
# {'Largest_fund': 2116981, '_id': ObjectId('61167af198608fe75d514784')}

# %%
#fund에서 합만 가져와보자.
for i in db.funds.aggregate([{"$project":{"name":1,"Largest_fund":{"$sum":"$funding_rounds.raised_amount"},"_id":0}},{"$sort":{"Largest_fund":-1}}]):
    pprint(i)
# Out:
# {'Largest_fund': 43298927, 'name': 'Facebook'}
# {'Largest_fund': 39027918, 'name': 'Baemin'}
# {'Largest_fund': 31324562, 'name': 'Daum'}
# {'Largest_fund': 31101921, 'name': 'Naver'}
# {'Largest_fund': 28746266, 'name': 'Line'}
# {'Largest_fund': 25113407, 'name': 'Google'}
# {'Largest_fund': 21826360, 'name': 'Coupang'}
