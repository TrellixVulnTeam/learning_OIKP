# %%
path = "../../../encore_migo/py_workspace/data/youtubevideos.csv"

# %%
# %cd ../../../encore_migo/py_workspace/data/
# Out:
# C:\encore_migo\py_workspace\data

# %%
# %pwd
# Out:
# 'C:\\encore_migo\\py_workspace\\data'

# %%
# !mongoimport --help
# Out:
# Usage:
#   mongoimport <options> <connection-string> <file>
#
# Import CSV, TSV or JSON data into MongoDB. If no file is provided, mongoimport reads from stdin.
#
# Connection strings must begin with mongodb:// or mongodb+srv://.
#
# See http://docs.mongodb.com/database-tools/mongoimport/ for more information.
#
# general options:
#       /help                                       print usage
#       /version                                    print the tool version and
#                                                   exit
#       /config:                                    path to a configuration file
#
# verbosity options:
#   /v, /verbose:<level>                            more detailed log output
#                                                   (include multiple times for
#                                                   more verbosity, e.g. -vvvvv,
#                                                   or specify a numeric value,
# ...

# %%
# !mongoimport -d newdb -c gstore --type csv --fields * --file googleplaystore.csv
# Out:
# 2021-09-13T20:36:27.626+0900	connected to: mongodb://localhost/
# 2021-09-13T20:36:27.835+0900	10842 document(s) imported successfully. 0 document(s) failed to import.

# %%
# Out:
# 'C:\\encore_migo\\py_workspace\\data'

# %%
from pymongo import MongoClient
con = MongoClient("localhost",27017)
db = con.newdb

# %%
for i in db.gstore.find():
    print(i)
# Out:
# {'_id': ObjectId('613f378814fac489e509d35c'), '*': 'Photo Editor & Candy Camera & Grid & ScrapBook', 'field1': 'ART_AND_DESIGN', 'field2': 4.1, 'field3': 159, 'field4': '19M', 'field5': '10,000+', 'field6': 'Free', 'field7': 0, 'field8': 'Everyone', 'field9': 'Art & Design', 'field10': 'January 7, 2018', 'field11': '1.0.0', 'field12': '4.0.3 and up'}
# {'_id': ObjectId('613f378814fac489e509d35d'), '*': 'App', 'field1': 'Category', 'field2': 'Rating', 'field3': 'Reviews', 'field4': 'Size', 'field5': 'Installs', 'field6': 'Type', 'field7': 'Price', 'field8': 'Content Rating', 'field9': 'Genres', 'field10': 'Last Updated', 'field11': 'Current Ver', 'field12': 'Android Ver'}
# ...
