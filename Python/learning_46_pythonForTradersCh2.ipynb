# %% [markdown]
# ## Download API

# %%
import yfinance as yf
import numpy as np
import pandas as pd

# %%
mydata=yf.download("AAPL")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
mydata
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 1980-12-12    0.128348    0.128906    0.128348    0.128348    0.100751
# 1980-12-15    0.122210    0.122210    0.121652    0.121652    0.095495
# 1980-12-16    0.113281    0.113281    0.112723    0.112723    0.088485
# 1980-12-17    0.115513    0.116071    0.115513    0.115513    0.090676
# 1980-12-18    0.118862    0.119420    0.118862    0.118862    0.093304
# ...                ...         ...         ...         ...         ...
# 2021-07-13  144.029999  147.460007  143.630005  145.639999  145.639999
# 2021-07-14  148.100006  149.570007  147.679993  149.149994  149.149994
# 2021-07-15  149.240005  150.000000  147.089996  148.479996  148.479996
# 2021-07-16  148.460007  149.759995  145.880005  146.389999  146.389999
# 2021-07-19  143.750000  144.070007  141.669998  143.059998  143.059998
#
#                Volume
# Date
# 1980-12-12  469033600
# 1980-12-15  175884800
# 1980-12-16  105728000
# ...

# %%
mydata.to_csv('./writings/output.csv')

# %%
myinput = pd.read_csv("./writings/output.csv")

# %%
myinput.index +=1

# %%
myinput.head() #first five
# Out:
#          Date      Open      High       Low     Close  Adj Close     Volume
# 1  1980-12-12  0.128348  0.128906  0.128348  0.128348   0.100751  469033600
# 2  1980-12-15  0.122210  0.122210  0.121652  0.121652   0.095495  175884800
# 3  1980-12-16  0.113281  0.113281  0.112723  0.112723   0.088485  105728000
# 4  1980-12-17  0.115513  0.116071  0.115513  0.115513   0.090676   86441600
# 5  1980-12-18  0.118862  0.119420  0.118862  0.118862   0.093304   73449600

# %%
fid = open('./writings/output.csv','r')

# %% [markdown]
# ## *Exercise 2.1*
# _Download price data for Google with the pandas data reader and specify a start and end date for the data._

# %%
# Solution

google = yf.download("GOOG")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
google.head(5)
# Out:
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2004-08-19  49.813290  51.835709  47.800831  49.982655  49.982655  44871361
# 2004-08-20  50.316402  54.336334  50.062355  53.952770  53.952770  22942874
# 2004-08-23  55.168217  56.528118  54.321388  54.495735  54.495735  18342897
# 2004-08-24  55.412300  55.591629  51.591621  52.239197  52.239197  15319808
# 2004-08-25  52.284027  53.798351  51.746044  52.802086  52.802086   9232276

# %%
google.tail(5)
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2021-07-13  2617.629883  2640.840088  2612.739990  2619.889893  2619.889893
# 2021-07-14  2638.030029  2659.919922  2637.959961  2641.649902  2641.649902
# 2021-07-15  2650.000000  2651.899902  2611.959961  2625.330078  2625.330078
# 2021-07-16  2632.820068  2643.659912  2616.429932  2636.909912  2636.909912
# 2021-07-19  2623.110107  2624.939941  2570.739990  2584.000000  2584.000000
#
#             Volume
# Date
# 2021-07-13  830900
# 2021-07-14  895600
# 2021-07-15  829300
# 2021-07-16  742800
# 2021-07-19  635919

# %% [markdown]
# ## *Exercise 2.2*
# *How long is the output and what data type is it?*

# %%
google['Open']
# Out:
# Date
# 2004-08-19      49.813290
# 2004-08-20      50.316402
# 2004-08-23      55.168217
# 2004-08-24      55.412300
# 2004-08-25      52.284027
#                  ...
# 2021-07-13    2617.629883
# 2021-07-14    2638.030029
# 2021-07-15    2650.000000
# 2021-07-16    2632.820068
# 2021-07-19    2623.110107
# Name: Open, Length: 4258, dtype: float64

# %%
len(google)
# Out:
# 4258

# %%
type(google)
# Out:
# pandas.core.frame.DataFrame

# %%
google.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
google.index
# Out:
# DatetimeIndex(['2004-08-19', '2004-08-20', '2004-08-23', '2004-08-24',
#                '2004-08-25', '2004-08-26', '2004-08-27', '2004-08-30',
#                '2004-08-31', '2004-09-01',
#                ...
#                '2021-07-06', '2021-07-07', '2021-07-08', '2021-07-09',
#                '2021-07-12', '2021-07-13', '2021-07-14', '2021-07-15',
#                '2021-07-16', '2021-07-19'],
#               dtype='datetime64[ns]', name='Date', length=4258, freq=None)

# %% [markdown]
# ## _Exercise 2.4_
# _Save the data in a csv file called 'output.csv'._

# %%
google.to_csv('./writings/output.csv')

# %%
datainput = pd.read_csv('./writings/output.csv')

# %%
datainput.index +=1

# %%
datainput.head(10)
# Out:
#           Date       Open       High        Low      Close  Adj Close  \
# 1   2004-08-19  49.813290  51.835709  47.800831  49.982655  49.982655
# 2   2004-08-20  50.316402  54.336334  50.062355  53.952770  53.952770
# 3   2004-08-23  55.168217  56.528118  54.321388  54.495735  54.495735
# 4   2004-08-24  55.412300  55.591629  51.591621  52.239197  52.239197
# 5   2004-08-25  52.284027  53.798351  51.746044  52.802086  52.802086
# 6   2004-08-26  52.279045  53.773445  52.134586  53.753517  53.753517
# 7   2004-08-27  53.848164  54.107193  52.647663  52.876804  52.876804
# 8   2004-08-30  52.443428  52.548038  50.814533  50.814533  50.814533
# 9   2004-08-31  50.958992  51.661362  50.889256  50.993862  50.993862
# 10  2004-09-01  51.158245  51.292744  49.648903  49.937820  49.937820
#
#       Volume
# 1   44871361
# 2   22942874
# 3   18342897
# 4   15319808
# 5    9232276
# 6    7128620
# 7    6241307
# 8    5221498
# 9    4941252
# 10   9181687

# %%
datainput["Mean"] = (datainput["High"] + datainput["Low"]) /2
#각각이 적용

# %%
datainput.head(5)
# Out:
#          Date       Open       High        Low      Close  Adj Close  \
# 1  2004-08-19  49.813290  51.835709  47.800831  49.982655  49.982655
# 2  2004-08-20  50.316402  54.336334  50.062355  53.952770  53.952770
# 3  2004-08-23  55.168217  56.528118  54.321388  54.495735  54.495735
# 4  2004-08-24  55.412300  55.591629  51.591621  52.239197  52.239197
# 5  2004-08-25  52.284027  53.798351  51.746044  52.802086  52.802086
#
#      Volume       Mean
# 1  44871361  49.818270
# 2  22942874  52.199345
# 3  18342897  55.424753
# 4  15319808  53.591625
# 5   9232276  52.772198

# %% [markdown]
# ## _Exercise 2.5_
# _Loop through the whole 'output.csv' file and do the daily range calculation. There is a little twist, see if you can figure it out._

# %%
datainput['Daily Range'] = (datainput['High']  -  datainput['Low']).rolling(5).mean()

# %%
datainput.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close  \
# 1  2004-08-19  49.813290  51.835709  47.800831  49.982655  49.982655
# 2  2004-08-20  50.316402  54.336334  50.062355  53.952770  53.952770
# 3  2004-08-23  55.168217  56.528118  54.321388  54.495735  54.495735
# 4  2004-08-24  55.412300  55.591629  51.591621  52.239197  52.239197
# 5  2004-08-25  52.284027  53.798351  51.746044  52.802086  52.802086
#
#      Volume       Mean  Daily Range
# 1  44871361  49.818270          NaN
# 2  22942874  52.199345          NaN
# 3  18342897  55.424753          NaN
# 4  15319808  53.591625          NaN
# 5   9232276  52.772198      3.31358

# %%
file_reader = open("./writings/output.csv")
file_reader.readline()
for i in file_reader:
    line = i.strip().split(',') #as it is csv file.
    high = float(line[2])
    low = float(line[3])
    print(high-low)
    print("========================")
# Out:
# 4.034877777099609
# ...
# 4.273979187011719
# ...
# 2.2067298889160156
# ...
# 4.000007629394531
# ...
# 2.05230712890625
# ...
# 1.6388587951660156
# ...
# 1.4595298767089844
# ...
# 1.7335052490234375
# ...
# 0.7721061706542969
# ...
# 1.6438407897949219
# ...
# 1.7085952758789062
# ...
# 1.2054824829101562
# ...
# 1.1905364990234375
# ...
# 1.2602767944335938
# ...
# 0.851806640625
# ...
# 2.62017822265625
# ...
# 0.9713592529296875
# ...
# 2.5952720642089844
# ...
# 2.007476806640625
# ...
# 2.0672531127929688
# ...
# 1.9626426696777344
# ...
# 2.4059829711914062
# ...
# 1.4495658874511719
# ...
# 1.4246597290039062
# ...
# 2.7945289611816406
# ...
# 2.1618995666503906
# ...
# 1.5342483520507812
# ...
# 3.581573486328125
# ...
# 4.378589630126953
# ...
# 1.6438369750976562
# ...
# 2.6600265502929688
# ...
# 1.4146957397460938
# ...
# 3.1332550048828125
# ...
# 1.220428466796875
# ...
# 1.658782958984375
# ...
# 1.3250350952148438
# ...
# 2.4956436157226562
# ...
# 2.097137451171875
# ...
# 1.7285232543945312
# ...
# 1.902862548828125
# ...
# 1.76837158203125
# ...
# 3.9800796508789062
# ...
# 2.5155715942382812
# ...
# 4.677467346191406
# ...
# 4.239112854003906
# ...
# 8.01495361328125
# ...
# 10.899147033691406
# ...
# 6.2964019775390625
# ...
